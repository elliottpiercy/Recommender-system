# %% [markdown]
# The Amazing Effectiveness of Sequence to Sequence Model for Time Series (Univariate). https://weiminwang.blog/2017/09/29/multivariate-time-series-forecast-using-seq2seq-in-tensorflow/

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import copy
import os
import pandas as pd
from sklearn import preprocessing
import csv

# FIX ARRAY AVERAGING FOR MULTIPLE SERIES. COMPRESS THE SERIES LIKE IN UNIVARIATE
# SHUFFLE HAS BEEN COMMENETED OUT. NEED TO AVERAGE, THEN RESHAPE THEN SHUFFLE.

# Run model using multivariate data
# Edit data handler to read weather data
# Write seq to seq bayesian code

# %%
training_size_mul = 1
input_seq_len = 252 * training_size_mul
output_seq_len = 63 * training_size_mul
batch_size = 230
X_compression = input_seq_len
Y_compression = output_seq_len

# Sunday: Try to make it a vanilla feedforward network
#         Fully understand how the validation set batch prediction works  
#         Implement validation set losses

# Questions for supervisor: Better data compression so i can expand the predictions to get an approximation
#                           Taking absolute values of negative points atm


# Need to try with full single time series. Exploratory data analysis of how the data changes over years.

# %%
# Data split
multivariate = np.empty((230,input_seq_len,11))

def split(data , num_windows, train_num=0.7 , val_num=0.15 , test_num=0.15 ):   # WRONG for multivariate case
# data.shape = (3630,10080)  -- all data windowed, needs to be split vertically into X and Y and horizonally into train/val etc
    window_month = int(8064/(32/training_size_mul))
    window_week = int(2016/(32/training_size_mul))

    train = np.empty((0,window_month + window_week))
    val = np.empty((0,window_month + window_week))
    test = np.empty((0,window_month + window_week))
    running_start = 0
    running_end = int(num_windows * train_num)

    print("Splitting data")
    for series in range(11):  #ERROR HERE!!! THE NUM OF HORIZONTAL WINDOWS SHOULDNT GET LARGER

        train = np.append(train,data[running_start:running_end],axis=0)

        running_start = running_end
        running_end = running_end + int(val_num * num_windows)

        val = np.append(val,data[running_start:running_end],axis=0)

        running_start = running_end
        running_end = running_end + int(test_num * num_windows)

        test = np.append(test,data[running_start:running_end],axis=0)

        running_start = series * num_windows
        running_end = running_start + int(train_num * num_windows)


    X_train = train[:,:window_month]
    Y_train = train[:,window_month:]

    X_val = val[:,:window_month]
    Y_val = val[:,window_month:]

    X_test = test[:,:window_month]
    Y_test = test[:,window_month:]
    print("Data split complete")
    print(X_train.shape)
    print(Y_train.shape)
    


    return X_train,Y_train,X_val,Y_val,X_test,Y_test



def window(data):   # Implement window. Ensuring to shuffle data with a seed.
    np.random.seed(1)
    window_month = int(8064/(32/training_size_mul))
    window_week = int(2016/(32/training_size_mul))
    num_windows = int(np.floor((len(data[0]) - (window_month + window_week))/int(288/(32/training_size_mul))))
    

    shuffle_and_window = np.empty((0,window_month + window_week))
    for row in range(11):
        data_in_use = data[row]
        windows = np.empty((0,window_month + window_week))
        running_start = 0
        running_end = window_month + window_week
        for index in range(num_windows):


            input_window = np.reshape(data_in_use[running_start:running_end],(1,window_month + window_week))
            windows = np.append(windows,input_window,axis=0)

            running_start = running_start + int(288/(32/training_size_mul)) #next day
            running_end = running_end + int(288/(32/training_size_mul))     #next day

#         np.random.shuffle(windows)  # shuffle with constant seed so each section is shuffled the same
        shuffle_and_window = np.append(shuffle_and_window,windows,axis=0)
        print("Series",row+1,"windowed and shuffled")

    return shuffle_and_window,num_windows # each 302(num_windows which will change as more years are included) rows corresponds to a time series. Each row is a different window



def removeNaN(data):
    index = np.argwhere(np.isnan(data[1]))
    try:
        data = np.delete(data, index, 1)  # delete indexs from all columns
    except IOError:
        print("XXX Remove NaN Error! XXX Data initialistion error! XXX")
    return data


def scaling(data):   # Scale data

    scaling_factors = np.array([])
    scaling_biases = np.array([])

    for row in range(11):

        current_data = data[row]

        scaling_factor = np.ptp(current_data)
        scaling_factors = np.append(scaling_factors,scaling_factor)
        scaling_bias = np.min(current_data)

        scaling_biases = np.append(scaling_biases,scaling_bias )
        data[row] = (current_data - scaling_bias)/scaling_factor

    # data = preprocessing.scale(data)  0 mean/unit variance???
    return data, scaling_factors, scaling_biases

def avg_array(data,batch_size,step):
    new_data = np.array([])
    for batch in range(11):
        temp = data.T[batch]
        for index in range(0,data.shape[1],step):
            new_data = np.append(new_data,np.mean(temp[index:index+step]))
    return np.reshape(new_data,(11,int(new_data.shape[0]/11)))

def data_reshaped(X_train,Y_train,X_val,Y_val,X_test,Y_test):
    X_train = np.reshape(X_train,(int(X_train.shape[0]/11),int(8064/(32/training_size_mul)),11))
    X_val = np.reshape(X_val,(int(X_val.shape[0]/11),int(8064/(32/training_size_mul)),11))
    X_test = np.reshape(X_test,(int(X_test.shape[0]/11),int(8064/(32/training_size_mul)),11))
    Y_train = np.reshape(Y_train,(int(Y_train.shape[0]/11),int(2016/(32/training_size_mul)),11))
    Y_val = np.reshape(Y_val,(int(Y_val.shape[0]/11),int(2016/(32/training_size_mul)),11))
    Y_test = np.reshape(Y_test,(int(Y_test.shape[0]/11),int(2016/(32/training_size_mul)),11))
    return X_train,X_val,X_test,Y_train,Y_val,Y_test
    
tester = np.reshape(X_train,(int(X_train.shape[0]/11),int(8064/(32/training_size_mul)),11))

def handler(year_from,year_to):  # Reads in the data
    data = np.array([])
    for year in range(year_from,year_to):
        directory_year = "20"+str(year)
        for month in range(1,13):   #loops though months
            if month < 10:
                directory = "Energy_load/" + directory_year + "-0" + str(month)

            else:
                directory = "Energy_load/"+ directory_year + "-" + str(month)

            path, dirs, files = os.walk(directory).__next__()
            days_in_month = len(files)

            if "Energy_load/2017-04" == "Energy_load/"+directory_year+"-0"+str(month) or "Energy_load/2016-03" == "Energy_load/"+directory_year+"-0"+str(month):   #SKIP APRIL 2017 ATM DUE TO LACK OF DATA ON NYISO SITE
                print("Ignoring 2017-04 and 2016-03 for now due to incomplete data")
                continue
            print("Currently reading "+directory_year+"-"+str(month))

            for day in range(1,days_in_month+1): #loops though days in that month

                if day < 10:
                    if month < 10:
                        file_location = directory + "/" + str(directory_year) + "0" + str(month) + "0" + str(day) + "pal.csv"
                    else:
                        file_location = directory + "/" + str(directory_year) +  str(month) + "0" + str(day) + "pal.csv"

                else:
                    if month < 10:
                        file_location = directory + "/" + str(directory_year) + "0" + str(month) + str(day) + "pal.csv"
                    else:
                        file_location = directory + "/" + str(directory_year) +  str(month) + str(day) + "pal.csv"

                file = pd.read_csv(file_location)
                df1 = file[['Load']]
                df2 = file[['Time Stamp']]
                
                input = np.array(df1)
                time_stamps = np.array(df2)
                
                items_to_delete = np.array([])
                for i in range(len(time_stamps)):
                    stamp = str(time_stamps[i]).split(':')
                    stamp = str(stamp[1][1:2])
                    if stamp != '0' and stamp !='5':
                        items_to_delete = np.append(items_to_delete,i)
                
                input = np.delete(input,items_to_delete)            

                data = np.append(data,np.absolute(input))  # currently taking the absolute values

    data = np.reshape(data,(int(len(data)/11),11)).T        # Reshape
    data = removeNaN(data)                      # Remove NaN values
    data = avg_array(data,batch_size,int(32/training_size_mul))
    data, scaling_factors, scaling_biases = scaling(data)   # Scale
    data_windowed_and_shuffled , num_windows = window(data) # Window and shuffle data -- each 302(num_windows which will change as more years are included) rows                                                                                                              corresponds to a time series.
# #                                                             # Each row is a different window for that series respectively

    print(data_windowed_and_shuffled.shape,num_windows)
    X_train,Y_train,X_val,Y_val,X_test,Y_test = split(data_windowed_and_shuffled ,num_windows, 0.7 , 0.15, 0.15)                   # 70/15/15 split
    X_train,X_val,X_test,Y_train,Y_val,Y_test = data_reshaped(X_train,Y_train,X_val,Y_val,X_test,Y_test)
    
    return X_train,Y_train,X_val,Y_val,X_test,Y_test,scaling_factors,scaling_biases

X_train,Y_train,X_val,Y_val,X_test,Y_test,scaling_factors,scaling_biases = handler(14,15)
print("Complete")
# Out:
# Currently reading 2014-1
# c:\users\ellio\documents\miniconda3\lib\site-packages\ipykernel_launcher.py:176: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# Currently reading 2014-2
# Currently reading 2014-3
# Currently reading 2014-4
# Currently reading 2014-5
# Currently reading 2014-6
# Currently reading 2014-7
# Currently reading 2014-8
# Currently reading 2014-9
# Currently reading 2014-10
# Currently reading 2014-11
# Currently reading 2014-12
# c:\users\ellio\documents\miniconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\ellio\documents\miniconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Series 1 windowed and shuffled
# Series 2 windowed and shuffled
# Series 3 windowed and shuffled
# Series 4 windowed and shuffled
# Series 5 windowed and shuffled
# Series 6 windowed and shuffled
# Series 7 windowed and shuffled
# Series 8 windowed and shuffled
# Series 9 windowed and shuffled
# Series 10 windowed and shuffled
# Series 11 windowed and shuffled
# (3630, 315) 330
# Splitting data
# Data split complete
# (2530, 252)
# (2530, 63)
# Complete
# c:\users\ellio\documents\miniconda3\lib\site-packages\numpy\core\fromnumeric.py:52: RuntimeWarning: invalid value encountered in reduce
#   return getattr(obj, method)(*args, **kwds)
# c:\users\ellio\documents\miniconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)

# %%
# def avg_array(data,batch_size,step):
#     new_data = np.array([])
#     for series in range(11):
#         for batch in range(batch_size):
#             temp = data[1]
#             for index in range(0,len(data[0]),step):
#                 new_data = np.append(new_data,np.mean(temp[index:index+step]))
#     return new_data

# # X_compression = 252 * training_size_mul


# # test = X_train
# # test = np.reshape(test,(230,8064,11))
# # test = avg_array(test,230,32)
# # test = np.reshape(test,(batch_size,X_compression,11))
# print(test.shape)

print(X_train.shape)
print(Y_train.shape) #ERROR HERE!!! THE WINDOW SIZE SHOULD BE SMALLER THAN X_TRAIN!!!
# Out:
# (230, 252, 11)
# (230, 63, 11)

# %%
def avg_array(data,batch_size,step):
    new_data = np.array([])
    for batch in range(batch_size):
        temp = data[batch]
        for index in range(0,len(data[0]),step):
            new_data = np.append(new_data,np.mean(temp[index:index+step]))
    return new_data

step = int(32/training_size_mul) #must be a mul of 2
batch_size = 211
X_compression = 252 * training_size_mul
Y_compression = 63 * training_size_mul


s1_X_train = np.reshape(avg_array(X_train[:batch_size],batch_size,step),(batch_size,X_compression))
s1_Y_train = np.reshape(avg_array(Y_train[:batch_size],batch_size,step),(batch_size,Y_compression))
s1_X_val = np.reshape(avg_array(X_val[:batch_size],batch_size,step),(batch_size,X_compression))
s1_Y_val = np.reshape(avg_array(Y_val[:batch_size],batch_size,step),(batch_size,Y_compression))
print("Series 1 initialised")

s2_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 2],batch_size,step),(batch_size,X_compression))
s2_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 2],batch_size,step),(batch_size,Y_compression))
s2_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 2],batch_size,step),(batch_size,X_compression))
s2_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 2],batch_size,step),(batch_size,Y_compression))
print("Series 2 initialised")

s3_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 3],batch_size,step),(batch_size,X_compression))
s3_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 3],batch_size,step),(batch_size,Y_compression))
s3_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 3],batch_size,step),(batch_size,X_compression))
s3_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 3],batch_size,step),(batch_size,Y_compression))
print("Series 3 initialised")

s4_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 4],batch_size,step),(batch_size,X_compression))
s4_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 4],batch_size,step),(batch_size,Y_compression))
s4_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 4],batch_size,step),(batch_size,X_compression))
s4_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 4],batch_size,step),(batch_size,Y_compression))
print("Series 4 initialised")

s5_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 5],batch_size,step),(batch_size,X_compression))
s5_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 5],batch_size,step),(batch_size,Y_compression))
s5_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 5],batch_size,step),(batch_size,X_compression))
s5_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 5],batch_size,step),(batch_size,Y_compression))
print("Series 5 initialised")

s6_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 6],batch_size,step),(batch_size,X_compression))
s6_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 6],batch_size,step),(batch_size,Y_compression))
s6_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 6],batch_size,step),(batch_size,X_compression))
s6_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 6],batch_size,step),(batch_size,Y_compression))
print("Series 6 initialised")

s7_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 7],batch_size,step),(batch_size,X_compression))
s7_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 7],batch_size,step),(batch_size,Y_compression))
s7_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 7],batch_size,step),(batch_size,X_compression))
s7_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 7],batch_size,step),(batch_size,Y_compression))
print("Series 7 initialised")

s8_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 8],batch_size,step),(batch_size,X_compression))
s8_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 8],batch_size,step),(batch_size,Y_compression))
s8_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 8],batch_size,step),(batch_size,X_compression))
s8_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 8],batch_size,step),(batch_size,Y_compression))
print("Series 8 initialised")

s9_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 9],batch_size,step),(batch_size,X_compression))
s9_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 9],batch_size,step),(batch_size,Y_compression))
s9_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 9],batch_size,step),(batch_size,X_compression))
s9_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 9],batch_size,step),(batch_size,Y_compression))
print("Series 9 initialised")

s10_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 10],batch_size,step),(batch_size,X_compression))
s10_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 10],batch_size,step),(batch_size,Y_compression))
s10_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 10],batch_size,step),(batch_size,X_compression))
s10_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 10],batch_size,step),(batch_size,Y_compression))
print("Series 10 initialised")

s11_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 11],batch_size,step),(batch_size,X_compression))
s11_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 11],batch_size,step),(batch_size,Y_compression))
s11_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 11],batch_size,step),(batch_size,X_compression))
s11_Y_val = np.reshape(avg_array(Y_val[batch_size:batch_size * 11],batch_size,step),(batch_size,Y_compression))
print("Series 11 initialised")
# Out:
# Series 1 initialised
# Series 2 initialised
# Series 3 initialised
# Series 4 initialised
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8ee26bf475a6> in <module>()
#      37 print("Series 4 initialised")
#      38
# ---> 39 s5_X_train = np.reshape(avg_array(X_train[batch_size:batch_size * 5],batch_size,step),(batch_size,X_compression))
#      40 s5_Y_train = np.reshape(avg_array(Y_train[batch_size:batch_size * 5],batch_size,step),(batch_size,Y_compression))
#      41 s5_X_val = np.reshape(avg_array(X_val[batch_size:batch_size * 5],batch_size,step),(batch_size,X_compression))
#
# <ipython-input-22-8ee26bf475a6> in avg_array(data, batch_size, step)
#       4         temp = data[batch]
#       5         for index in range(0,len(data[0]),step):
# ----> 6             new_data = np.append(new_data,np.mean(temp[index:index+step]))
#       7     return new_data
#       8
#
# c:\users\ellio\documents\miniconda3\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    5164         values = ravel(values)
#    5165         axis = arr.ndim-1
# -> 5166     return concatenate((arr, values), axis=axis)
#
# KeyboardInterrupt:

# %%
# Code for testing

test = np.array([])
test_batch_size = 210

print(len(X_train[210])) 

def avg_array(data,batch_size,step):
    new_data = np.array([])
    for batch in range(batch_size):
        temp = X_train[batch_size]
#         print("Batch",batch)
#         print(len(temp))
        for index in range(0,len(data[0]),step):
#             print(temp[index:index+step])
            new_data = np.append(new_data,np.mean(temp[index:index+step]))
    return new_data


test = avg_array(X_train,test_batch_size,32)
test = np.reshape(test,(test_batch_size,252))                       
print(test.shape)
print("Done")

# %%
# Code for testing

for index in range(32,len(Y_train[0]),32):
#     print(np.mean(Y_train.T[index-32:index]))
    new_Y_train = np.append(new_Y_train,np.mean(Y_train.T[index-32:index]))
print(new_Y_train.shape)

# %%
# Code for testing
for batch in range(210):
    temp = X_train[batch]
    print(temp)

# %%
# CODE FOR UNIVARIATE

new_Y_train = np.array([])
new_X_train = np.array([])
new_X_val = np.array([])
new_Y_val = np.array([])


# def avg_array(data,batch_size,step):
#     new_data = np.array([])
#     for batch in range(batch_size):
#         for index in range(0,len(data[1]),step):
#             new_data = np.append(new_data,np.mean(data.T[index:index+step][batch]))
#     return(new_data)

# def avg_array(data,batch_size,step):
#     new_data = np.array([])
#     for batch in range(batch_size):
#         if batch%100 == 0:
#             print(batch)
#         temp = X_train.T[batch_size]
#         for index in range(0,len(data[0]),step):
#             new_data = np.append(new_data,np.mean(temp[index:index+step]))
#     return new_data

def avg_array(data,batch_size,step):
    new_data = np.array([])
    for batch in range(batch_size):
        temp = data[batch]
        for index in range(0,len(data[0]),step):
            new_data = np.append(new_data,np.mean(temp[index:index+step]))
    return new_data

step = int(32/training_size_mul) #must be a mul of 2
batch_size = 211

new_X_train = avg_array(X_train,batch_size,step)
print("new_X_train initialised")

new_X_val = avg_array(X_val,batch_size,step)
print("new_X_val initialised")

new_Y_val = avg_array(Y_val,batch_size,step)
print("new_Y_val initialised")

new_Y_train = avg_array(Y_train,batch_size,step)
print("new_Y_train initialised")

print(new_X_train.shape)
print(new_Y_train.shape)
print(new_X_val.shape)
print(new_Y_val.shape)
# Out:
# new_X_train initialised
# new_X_val initialised
# new_Y_val initialised
# new_Y_train initialised
# (212688,)
# (53172,)
# (212688,)
# (53172,)

# %%
# RESHAPING CODE FOR UNIVARIATE 
X_compression = 252 * training_size_mul
Y_compression = 63 * training_size_mul

new_X_train = np.reshape(new_X_train,(batch_size,X_compression))
new_Y_train = np.reshape(new_Y_train,(batch_size,Y_compression))
new_X_val = np.reshape(new_X_val,(batch_size,X_compression))
new_Y_val = np.reshape(new_Y_val,(batch_size,Y_compression))

# %%
input_seq_len = 15
output_seq_len = 20
batch_size = 50
x = np.linspace(0, 40, 130)
train_data_x = x[:(130 - output_seq_len)]
 
def true_output_signals(x):
    x1 = 2 * np.sin(x)
    x2 = 2 * np.cos(x)
    return x1, x2
 
def true_input_signals(x):
    x1, x2 = true_output_signals(x)
    y1 = 1.6*x1**4 - 2*x2 - 10
    y2 = 1.2*x2**2 * x1 + 2*x2*3 - x1*6
    y3 = 2*x1**3 + 2*x2**3 - x1*x2
    return y1, y2, y3
 
def noise_func(x, noise_factor = 2):
    return np.random.randn(len(x)) * noise_factor
 
def generate_samples_for_output(x):
    x1, x2 = true_output_signals(x)
    return x1+noise_func(x1, 0.5), \
           x2+noise_func(x2, 0.5)
 
def generate_samples_for_input(x):
    y1, y2, y3 = true_input_signals(x)
    return y1+noise_func(y1, 2), \
           y2+noise_func(y2, 2), \
           y3+noise_func(y3, 2)
 
def generate_train_samples(x = train_data_x, batch_size = 10):
 
    total_start_points = len(x) - input_seq_len - output_seq_len
    start_x_idx = np.random.choice(range(total_start_points), batch_size)
 
    input_seq_x = [x[i:(i+input_seq_len)] for i in start_x_idx]
    output_seq_x = [x[(i+input_seq_len):(i+input_seq_len+output_seq_len)] for i in start_x_idx]
 
    input_seq_y = [generate_samples_for_input(x) for x in input_seq_x]
    output_seq_y = [generate_samples_for_output(x) for x in output_seq_x]
 
    ## return shape: (batch_size, time_steps, feature_dims)
    return np.array(input_seq_y).transpose(0, 2, 1), np.array(output_seq_y).transpose(0, 2, 1)

def get_train_data(i):
    if i == 200:
        return new_X_train[i:],new_Y_train[i:]
    else:
        return new_X_train[i:i+10],new_Y_train[i:i+10]

def get_val_data():
    return new_X_val,new_Y_val

#def get_val_data_loop():
#    return np.reshape(new_X_val[1],(1,252)), np.reshape(new_Y_val[1],(1,63))

# for i in range(0,batch_size-10,10):
#     b_in,b_out = get_train_data(i)
#     print(b_in.shape)

# %%
# input_seq_len = 20
# output_seq_len = 15
# batch_size = 32
 
x = np.linspace(0, 1000,1000)
train_data_x = x[:(1000-output_seq_len)]
 
def true_signal(x):
    y = 2 * np.sin(x)
    return y
 
def noise_func(x, noise_factor = 0.5):
    return np.random.randn(len(x)) * noise_factor
 
def generate_y_values(x):
    return true_signal(x) + noise_func(x)
 
def generate_train_samples(x = train_data_x, batch_size = 10, input_seq_len = 15, output_seq_len = 20):
 
    total_start_points = len(x) - input_seq_len - output_seq_len
    start_x_idx = np.random.choice(range(total_start_points), batch_size)
 
    input_seq_x = [x[i:(i+input_seq_len)] for i in start_x_idx]
    output_seq_x = [x[(i+input_seq_len):(i+input_seq_len+output_seq_len)] for i in start_x_idx]
 
    input_seq_y = [generate_y_values(x) for x in input_seq_x]
    output_seq_y = [generate_y_values(x) for x in output_seq_x]
 
    ## return shape: (batch_size, time_steps, feature_dims)
   
    return np.array(input_seq_y), np.array(output_seq_y)

def get_train_data():
    return new_X_train,new_Y_train

def get_val_data():
    return new_X_val,new_Y_val

#def get_val_data_loop():
#    return np.reshape(new_X_val[1],(1,252)), np.reshape(new_Y_val[1],(1,63))

# %%
input_seq, output_seq = generate_train_samples(batch_size=100)
 
# l1, = plt.plot(range(input_seq_len), input_seq[1], 'go', label = 'input sequence for one sample')
# l2, = plt.plot(range(input_seq_len, input_seq_len+output_seq_len), output_seq[1], 'ro', label = 'output sequence for one sample')
# plt.legend(handles = [l1, l2], loc = 'lower left')
# plt.show()
new_X_val,new_Y_val = get_val_data()
print(new_X_val[0].shape)

# %%
# Define decoder and Seq2SeqRNN

def _rnn_decoder(decoder_inputs,
                initial_state,
                cell,
                loop_function=None,
                scope=None):
  """RNN decoder for the sequence-to-sequence model.
  Args:
    decoder_inputs: A list of 2D Tensors [batch_size, input_size].
    initial_state: 2D Tensor with shape [batch_size, cell.state_size].
    cell: rnn_cell.RNNCell defining the cell function and size.
    loop_function: If not None, this function will be applied to the i-th output
      in order to generate the i+1-st input, and decoder_inputs will be ignored,
      except for the first element ("GO" symbol). This can be used for decoding,
      but also for training to emulate http://arxiv.org/abs/1506.03099.
      Signature -- loop_function(prev, i) = next
        * prev is a 2D Tensor of shape [batch_size x output_size],
        * i is an integer, the step number (when advanced control is needed),
        * next is a 2D Tensor of shape [batch_size x input_size].
    scope: VariableScope for the created subgraph; defaults to "rnn_decoder".
  Returns:
    A tuple of the form (outputs, state), where:
      outputs: A list of the same length as decoder_inputs of 2D Tensors with
        shape [batch_size x output_size] containing generated outputs.
      state: The state of each cell at the final time-step.
        It is a 2D Tensor of shape [batch_size x cell.state_size].
        (Note that in some cases, like basic RNN cell or GRU cell, outputs and
         states can be the same. They are different for LSTM cells though.)
  """
  with variable_scope.variable_scope(scope or "rnn_decoder"):
    state = initial_state
    outputs = []
    prev = None
    for i, inp in enumerate(decoder_inputs):
      if loop_function is not None and prev is not None:
        with variable_scope.variable_scope("loop_function", reuse=True):
          inp = loop_function(prev, i)
      if i > 0:
        variable_scope.get_variable_scope().reuse_variables()
      output, state = cell(inp, state)
      outputs.append(output)
      if loop_function is not None:
        prev = output
  return outputs, state
 
def _basic_rnn_seq2seq(encoder_inputs,
                      decoder_inputs,
                      cell,
                      feed_previous,
                      dtype= tf.float32,
                      scope=None):
  """Basic RNN sequence-to-sequence model.
  This model first runs an RNN to encode encoder_inputs into a state vector,
  then runs decoder, initialized with the last encoder state, on decoder_inputs.
  Encoder and decoder use the same RNN cell type, but don't share parameters.
  Args:
    encoder_inputs: A list of 2D Tensors [batch_size x input_size].
    decoder_inputs: A list of 2D Tensors [batch_size x input_size].
    feed_previous: Boolean; if True, only the first of decoder_inputs will be
      used (the "GO" symbol), all other inputs will be generated by the previous
      decoder output using _loop_function below. If False, decoder_inputs are used
      as given (the standard decoder case).
    dtype: The dtype of the initial state of the RNN cell (default: tf.float32).
    scope: VariableScope for the created subgraph; default: "basic_rnn_seq2seq".
  Returns:
    A tuple of the form (outputs, state), where:
      outputs: A list of the same length as decoder_inputs of 2D Tensors with
        shape [batch_size x output_size] containing the generated outputs.
      state: The state of each decoder cell in the final time-step.
        It is a 2D Tensor of shape [batch_size x cell.state_size].
  """
  with variable_scope.variable_scope(scope or "basic_rnn_seq2seq"):
    enc_cell = copy.deepcopy(cell)
    _, enc_state = rnn.static_rnn(enc_cell, encoder_inputs, dtype=dtype)
    if feed_previous:
        return _rnn_decoder(decoder_inputs, enc_state, cell, _loop_function)
    else:
        return _rnn_decoder(decoder_inputs, enc_state, cell)
 
def _loop_function(prev, _):
  '''Naive implementation of loop function for _rnn_decoder. Transform prev from
  dimension [batch_size x hidden_dim] to [batch_size x output_dim], which will be
  used as decoder input of next time step '''
  return tf.matmul(prev, weights['out']) + biases['out']

# %%
#Defining graph and hyperparameters

from tensorflow.contrib import rnn
from tensorflow.python.ops import variable_scope
from tensorflow.python.framework import dtypes
 
## Parameters
learning_rate = 0.01
lambda_l2_reg = 0.003 
 
## Network Parameters
# length of input signals
input_seq_len = input_seq_len
# length of output signals
output_seq_len = output_seq_len
# size of LSTM Cell
hidden_dim = 128
# num of input signals
input_dim = 11
# num of output signals
output_dim = 11
# num of stacked lstm layers
num_stacked_layers = 1
# gradient clipping - to avoid gradient exploding
GRADIENT_CLIPPING = 2.5
 
def build_graph(feed_previous = False):
    print("Building graph")
 
    tf.reset_default_graph()
 
    global_step = tf.Variable(
                  initial_value=0,
                  name="global_step",
                  trainable=False,
                  collections=[tf.GraphKeys.GLOBAL_STEP, tf.GraphKeys.GLOBAL_VARIABLES])
 
    weights = {
        'out': tf.get_variable('Weights_out', \
                               shape = [hidden_dim, output_dim], \
                               dtype = tf.float32, \
                               initializer = tf.truncated_normal_initializer()),
    }
    print("    - Weights init")
    
    biases = {
        'out': tf.get_variable('Biases_out', \
                               shape = [output_dim], \
                               dtype = tf.float32, \
                               initializer = tf.constant_initializer(0.)),
    }
    print("    - Biases init")
    with tf.variable_scope('Seq2seq'):
        # Encoder: inputs
        enc_inp = [
            tf.placeholder(tf.float32, shape=(None, input_dim), name="inp_{}".format(t))
               for t in range(input_seq_len)
        ]
 
        # Decoder: target outputs
        target_seq = [
            tf.placeholder(tf.float32, shape=(None, output_dim), name="y".format(t))
              for t in range(output_seq_len)
        ]
 
        # Give a "GO" token to the decoder.
        # If dec_inp are fed into decoder as inputs, this is 'guided' training; otherwise only the
        # first element will be fed as decoder input which is then 'un-guided'
        dec_inp = [ tf.zeros_like(target_seq[0], dtype=tf.float32, name="GO") ] + target_seq[:-1]
        
        with tf.variable_scope('LSTMCell'):
            cells = []
            for i in range(num_stacked_layers):
                with tf.variable_scope('RNN_{}'.format(i)):
                    cells.append(tf.contrib.rnn.LSTMCell(hidden_dim))
            cell = tf.contrib.rnn.MultiRNNCell(cells)
 
        def _rnn_decoder(decoder_inputs,
                        initial_state,
                        cell,
                        loop_function=None,
                        scope=None):
          """RNN decoder for the sequence-to-sequence model.
          Args:
            decoder_inputs: A list of 2D Tensors [batch_size x input_size].
            initial_state: 2D Tensor with shape [batch_size x cell.state_size].
            cell: rnn_cell.RNNCell defining the cell function and size.
            loop_function: If not None, this function will be applied to the i-th output
              in order to generate the i+1-st input, and decoder_inputs will be ignored,
              except for the first element ("GO" symbol). This can be used for decoding,
              but also for training to emulate http://arxiv.org/abs/1506.03099.
              Signature -- loop_function(prev, i) = next
                * prev is a 2D Tensor of shape [batch_size x output_size],
                * i is an integer, the step number (when advanced control is needed),
                * next is a 2D Tensor of shape [batch_size x input_size].
            scope: VariableScope for the created subgraph; defaults to "rnn_decoder".
          Returns:
            A tuple of the form (outputs, state), where:
              outputs: A list of the same length as decoder_inputs of 2D Tensors with
                shape [batch_size x output_size] containing generated outputs.
              state: The state of each cell at the final time-step.
                It is a 2D Tensor of shape [batch_size x cell.state_size].
                (Note that in some cases, like basic RNN cell or GRU cell, outputs and
                 states can be the same. They are different for LSTM cells though.)
          """
          with variable_scope.variable_scope(scope or "rnn_decoder"):
            state = initial_state
            outputs = []
            prev = None
            for i, inp in enumerate(decoder_inputs):
              if loop_function is not None and prev is not None:
                with variable_scope.variable_scope("loop_function", reuse=True):
                  inp = loop_function(prev, i)
              if i > 0:
                variable_scope.get_variable_scope().reuse_variables()
              output, state = cell(inp, state)
              outputs.append(output)
              if loop_function is not None:
                prev = output
          return outputs, state
 
        def _basic_rnn_seq2seq(encoder_inputs,
                              decoder_inputs,
                              cell,
                              feed_previous,
                              dtype=dtypes.float32,
                              scope=None):
          """Basic RNN sequence-to-sequence model.
          This model first runs an RNN to encode encoder_inputs into a state vector,
          then runs decoder, initialized with the last encoder state, on decoder_inputs.
          Encoder and decoder use the same RNN cell type, but don't share parameters.
          Args:
            encoder_inputs: A list of 2D Tensors [batch_size x input_size].
            decoder_inputs: A list of 2D Tensors [batch_size x input_size].
            feed_previous: Boolean; if True, only the first of decoder_inputs will be
              used (the "GO" symbol), all other inputs will be generated by the previous
              decoder output using _loop_function below. If False, decoder_inputs are used
              as given (the standard decoder case).
            dtype: The dtype of the initial state of the RNN cell (default: tf.float32).
            scope: VariableScope for the created subgraph; default: "basic_rnn_seq2seq".
          Returns:
            A tuple of the form (outputs, state), where:
              outputs: A list of the same length as decoder_inputs of 2D Tensors with
                shape [batch_size x output_size] containing the generated outputs.
              state: The state of each decoder cell in the final time-step.
                It is a 2D Tensor of shape [batch_size x cell.state_size].
          """
          with variable_scope.variable_scope(scope or "basic_rnn_seq2seq"):
            enc_cell = copy.deepcopy(cell)
            _, enc_state = rnn.static_rnn(enc_cell, encoder_inputs, dtype=dtype)
            if feed_previous:
                return _rnn_decoder(decoder_inputs, enc_state, cell, _loop_function)
            else:
                return _rnn_decoder(decoder_inputs, enc_state, cell)
 
        def _loop_function(prev, _):
          '''Naive implementation of loop function for _rnn_decoder. Transform prev from
          dimension [batch_size x hidden_dim] to [batch_size x output_dim], which will be
          used as decoder input of next time step '''
          return tf.matmul(prev, weights['out']) + biases['out']
 
        dec_outputs, dec_memory = _basic_rnn_seq2seq(
            enc_inp,
            dec_inp,
            cell,
            feed_previous = feed_previous
        )
 
        reshaped_outputs = [tf.matmul(i, weights['out']) + biases['out'] for i in dec_outputs]
 
    # Training loss and optimizer
    with tf.variable_scope('Loss'):
        # L2 loss
        output_loss = 0
        for _y, _Y in zip(reshaped_outputs, target_seq):
            output_loss += tf.reduce_mean(tf.pow(_y - _Y, 2)) #MSE
 
        # L2 regularization for weights and biases
        reg_loss = 0
        for tf_var in tf.trainable_variables():
            if 'Biases_' in tf_var.name or 'Weights_' in tf_var.name:
                reg_loss += tf.reduce_mean(tf.nn.l2_loss(tf_var)) 
  
        loss = output_loss + lambda_l2_reg * reg_loss 
 
    with tf.variable_scope('Optimizer'):
        optimizer = tf.contrib.layers.optimize_loss(
                loss=loss,
                learning_rate=learning_rate,
                global_step=global_step,
                optimizer='Adam',
                clip_gradients=GRADIENT_CLIPPING)
 
    saver = tf.train.Saver
 
    return dict(
        enc_inp = enc_inp,
        target_seq = target_seq,
        train_op = optimizer,
        loss=loss,
        saver = saver,
        reshaped_outputs = reshaped_outputs,
        )

# %%
def rescale_data(data):
    return data*scaling_factors[0] + scaling_biases[0]

def mse(data,new_data):
    return np.mean((data-new_data)**2)

def mape(data,new_data):
    return np.mean(np.abs((data - new_data) / data)) * 100

# %%
# Train model

epochs = 40
total_iteractions = 300
batch_size = batch_size
KEEP_RATE = 0.5
train_losses = []
val_losses = []
 
x = np.linspace(0, 1000,1000)
train_data_x = x[:(1000-output_seq_len)]

rnn_model = build_graph(feed_previous=False)
 
saver = tf.train.Saver()
print("Saver init")
init = tf.global_variables_initializer()
print("Started and initialised")
with tf.Session() as sess:
 
    sess.run(init)
    for e in range(epochs):
        for i in range(total_iteractions):
            print("Epoch",e+1,"Iteration",i+1)
#           batch_input, batch_output = generate_train_samples(batch_size=batch_size, input_seq_len = input_seq_len, output_seq_len = output_seq_len)
            batch_train_input, batch_train_output = get_train_data()
            

            feed_dict = {rnn_model['enc_inp'][t]: batch_train_input[:,t].reshape(-1,input_dim) for t in range(input_seq_len)} #input
            feed_dict.update({rnn_model['target_seq'][t]: batch_train_output[:,t].reshape(-1,output_dim) for t in range(output_seq_len)}) #target output
            _, loss_t = sess.run([rnn_model['train_op'], rnn_model['loss']], feed_dict)
            print(loss_t)
            train_losses = np.append(train_losses,loss_t)
            
#             batch_val_input,batch_val_output = get_val_data()
#             # Validation set 
#             feed_dict = {rnn_model['enc_inp'][t]: batch_val_input[t].reshape(1,1) for t in range(input_seq_len)}
#             feed_dict.update({rnn_model['target_seq'][t]: np.zeros([1, output_dim]) for t in range(output_seq_len)})
#             final_preds = sess.run(rnn_model['reshaped_outputs'], feed_dict)
            
#             val_losses = np.append(val_losses,mse(final_preds,batch_val_output[0]))

    
    temp_saver = rnn_model['saver']()
    save_path = temp_saver.save(sess, os.path.join('C:/Users/ellio/Documents/Dissertation/jupyter_code/Models/Univariate', 'univariate_ts_model0'))

print("Checkpoint saved at: ", save_path)

# %%
# Train model

np.random.seed(1)

epochs = 100
total_iteractions = 300
batch_size = batch_size
KEEP_RATE = 0.5
train_losses = []
val_losses = []
avg_val_losses = []
current_lowest = 10000
 
x = np.linspace(0, 1000,1000)
train_data_x = x[:(1000 - output_seq_len)]

rnn_model = build_graph(feed_previous=False)
 
saver = tf.train.Saver()
print("Saver init")
init = tf.global_variables_initializer()
print("Started and initialised")
with tf.Session() as sess:
 
    sess.run(init)
    for e in range(epochs):
        for i in range(total_iteractions):
            print("Epoch",e+1,"Iteration",i+1)
            batch_train_input, batch_train_output = get_train_data()

            feed_dict = {rnn_model['enc_inp'][t]: batch_train_input[:,t].reshape(-1,input_dim) for t in range(input_seq_len)} #input
            feed_dict.update({rnn_model['target_seq'][t]: batch_train_output[:,t].reshape(-1,output_dim) for t in range(output_seq_len)}) #target output
            _, loss_t = sess.run([rnn_model['train_op'], rnn_model['loss']], feed_dict)
            print(loss_t)
            train_losses = np.append(train_losses,loss_t)
            if loss_t < current_lowest:
                current_lowest = loss_t
                temp_saver = rnn_model['saver']()
                save_path = temp_saver.save(sess, os.path.join('C:/Users/ellio/Documents/Dissertation/jupyter_code/Models/Univariate/4x', 'univariate_ts_model0_4x'))

            
            
############# READ IN WHOLE BATCH AND EVALUATE ALL AT ONCE #############
            
#             batch_val_input,batch_val_output = get_val_data() 
#DELETED [:,t] FROM batch_val_input WHICH IS WHY IT WONT READ IN THE WHOLE BATCH AND ONLY 1 SEQUENCE AT ONCE!!!
#             print(batch_val_input.shape)
#             feed_dict = {rnn_model['enc_inp'][t]: batch_val_input.reshape(-1,input_dim) for t in range(input_seq_len)}
#             feed_dict.update({rnn_model['target_seq'][t]: np.zeros([1, output_dim]) for t in range(output_seq_len)})
#             final_preds = sess.run(rnn_model['reshaped_outputs'], feed_dict)
#             print(final_preds.shape) 
#             print(final_preds)

############# READ IN WHOLE BATCH AND EVALUATE ONE AT A TIME #############

#             val_losses = np.array([])
#             batch_val_input,batch_val_output = get_val_data()

#             for v in range(len(batch_val_input)):
                
#                 val_input = batch_val_input[v]
#                 feed_dict = {rnn_model['enc_inp'][t]: val_input[t].reshape(1,1) for t in range(input_seq_len)}
#                 feed_dict.update({rnn_model['target_seq'][t]: np.zeros([1, output_dim]) for t in range(output_seq_len)})
#                 final_preds = sess.run(rnn_model['reshaped_outputs'], feed_dict)

#                 val_losses = np.append(val_losses,mse(final_preds,batch_val_output[v]))
#             avg_val_losses = np.append(val_losses,np.mean(val_losses))
            
            
############# READ IN 1 VALIADATION ROW AND ONLY USE THAT #############
            batch_val_input,batch_val_output = get_val_data()
            batch_val_input = batch_val_input[0]
            feed_dict = {rnn_model['enc_inp'][t]: batch_val_input[t].reshape(1,input_dim) for t in range(input_seq_len)}
            feed_dict.update({rnn_model['target_seq'][t]: np.zeros([1, output_dim]) for t in range(output_seq_len)})
            final_preds = sess.run(rnn_model['reshaped_outputs'], feed_dict)

            val_losses = np.append(val_losses,mse(final_preds,batch_val_input))

    
    temp_saver = rnn_model['saver']()
    save_path = temp_saver.save(sess, os.path.join('C:/Users/ellio/Documents/Dissertation/jupyter_code/Models/Univariate/4x', 'univariate_ts_model0_4x'))

print("Checkpoint saved at: ", save_path)
print("Complete")
# Out:
# Building graph
#     - Weights init
#     - Biases init
# Saver init
# Started and initialised
# Epoch 1 Iteration 1
# 55.836567
# Epoch 1 Iteration 2
# 2965.8574
# Epoch 1 Iteration 3
# 69.77812
# Epoch 1 Iteration 4
# 325.4752
# Epoch 1 Iteration 5
# 81.88606
# Epoch 1 Iteration 6
# 1.5275345
# Epoch 1 Iteration 7
# 103.998764
# Epoch 1 Iteration 8
# 80.15151
# Epoch 1 Iteration 9
# 17.85857
# Epoch 1 Iteration 10
# 4.5378814
# Epoch 1 Iteration 11
# 6.833629
# Epoch 1 Iteration 12
# 0.8471124
# Epoch 1 Iteration 13
# 14.578538
# Epoch 1 Iteration 14
# 17.679586
# Epoch 1 Iteration 15
# 5.8226533
# Epoch 1 Iteration 16
# 1.1387391
# Epoch 1 Iteration 17
# 1.9360445
# Epoch 1 Iteration 18
# 0.5250861
# Epoch 1 Iteration 19
# 3.7408457
# Epoch 1 Iteration 20
# 5.287269
# Epoch 1 Iteration 21
# 2.2860599
# Epoch 1 Iteration 22
# 0.4876125
# Epoch 1 Iteration 23
# 0.76905155
# Epoch 1 Iteration 24
# 0.45965734
# Epoch 1 Iteration 25
# 1.3162543
# Epoch 1 Iteration 26
# 1.8848014
# Epoch 1 Iteration 27
# 0.9845671
# Epoch 1 Iteration 28
# 0.47329336
# Epoch 1 Iteration 29
# 0.6048475
# Epoch 1 Iteration 30
# 0.323649
# Epoch 1 Iteration 31
# 0.92623985
# Epoch 1 Iteration 32
# 1.3429639
# Epoch 1 Iteration 33
# 0.7509471
# Epoch 1 Iteration 34
# 0.36355603
# Epoch 1 Iteration 35
# 0.47737744
# Epoch 1 Iteration 36
# 0.2890256
# Epoch 1 Iteration 37
# 0.6379381
# Epoch 1 Iteration 38
# 0.8817067
# Epoch 1 Iteration 39
# 0.48768544
# Epoch 1 Iteration 40
# 0.3693154
# Epoch 1 Iteration 41
# 0.4923576
# Epoch 1 Iteration 42
# 0.2904442
# Epoch 1 Iteration 43
# 0.5131216
# Epoch 1 Iteration 44
# 0.7352428
# Epoch 1 Iteration 45
# 0.43031594
# Epoch 1 Iteration 46
# 0.30828506
# Epoch 1 Iteration 47
# 0.41612548
# Epoch 1 Iteration 48
# 0.26798394
# Epoch 1 Iteration 49
# 0.48724502
# Epoch 1 Iteration 50
# 0.6614746
# Epoch 1 Iteration 51
# 0.3752098
# Epoch 1 Iteration 52
# 0.30195552
# Epoch 1 Iteration 53
# 0.42437142
# Epoch 1 Iteration 54
# 0.27174598
# Epoch 1 Iteration 55
# 0.3827901
# Epoch 1 Iteration 56
# 0.52066064
# Epoch 1 Iteration 57
# 0.3079664
# Epoch 1 Iteration 58
# 0.32465446
# Epoch 1 Iteration 59
# 0.44687712
# Epoch 1 Iteration 60
# 0.27936995
# Epoch 1 Iteration 61
# 0.33429635
# Epoch 1 Iteration 62
# 0.45860904
# Epoch 1 Iteration 63
# 0.2810341
# Epoch 1 Iteration 64
# 0.31681037
# Epoch 1 Iteration 65
# 0.43343085
# Epoch 1 Iteration 66
# 0.27348536
# Epoch 1 Iteration 67
# 0.3108973
# Epoch 1 Iteration 68
# 0.41913873
# Epoch 1 Iteration 69
# 0.25921693
# Epoch 1 Iteration 70
# 0.32329443
# Epoch 1 Iteration 71
# 0.4462397
# Epoch 1 Iteration 72
# 0.2835688
# Epoch 1 Iteration 73
# 0.27294517
# Epoch 1 Iteration 74
# 0.36032313
# Epoch 1 Iteration 75
# 0.23197041
# Epoch 1 Iteration 76
# 0.34237766
# Epoch 1 Iteration 77
# 0.467303
# Epoch 1 Iteration 78
# 0.29561916
# Epoch 1 Iteration 79
# 0.24789089
# Epoch 1 Iteration 80
# 0.32313976
# Epoch 1 Iteration 81
# 0.21691544
# Epoch 1 Iteration 82
# 0.3477867
# Epoch 1 Iteration 83
# 0.47078055
# Epoch 1 Iteration 84
# 0.29953173
# Epoch 1 Iteration 85
# 0.23167858
# Epoch 1 Iteration 86
# 0.29535562
# Epoch 1 Iteration 87
# 0.20655154
# Epoch 1 Iteration 88
# 0.3592829
# Epoch 1 Iteration 89
# 0.49448103
# Epoch 1 Iteration 90
# 0.3212176
# Epoch 1 Iteration 91
# 0.21201053
# Epoch 1 Iteration 92
# 0.26912206
# Epoch 1 Iteration 93
# 0.20411597
# Epoch 1 Iteration 94
# 0.38700715
# Epoch 1 Iteration 95
# 0.5792186
# Epoch 1 Iteration 96
# 0.38909572
# Epoch 1 Iteration 97
# 0.22110239
# Epoch 1 Iteration 98
# 0.26659775
# Epoch 1 Iteration 99
# 0.23061995
# Epoch 1 Iteration 100
# 0.36988696
# Epoch 1 Iteration 101
# 0.47722596
# Epoch 1 Iteration 102
# 0.31403798
# Epoch 1 Iteration 103
# 0.22337236
# Epoch 1 Iteration 104
# 0.26203603
# Epoch 1 Iteration 105
# 0.18944147
# Epoch 1 Iteration 106
# 0.3485349
# Epoch 1 Iteration 107
# 0.4633911
# Epoch 1 Iteration 108
# 0.30217087
# Epoch 1 Iteration 109
# 0.21518235
# Epoch 1 Iteration 110
# 0.26086786
# Epoch 1 Iteration 111
# 0.18997341
# Epoch 1 Iteration 112
# 0.32068333
# Epoch 1 Iteration 113
# 0.42178917
# Epoch 1 Iteration 114
# 0.2705619
# Epoch 1 Iteration 115
# 0.20224339
# Epoch 1 Iteration 116
# 0.2546668
# Epoch 1 Iteration 117
# 0.18303525
# Epoch 1 Iteration 118
# 0.31469265
# Epoch 1 Iteration 119
# 0.4234396
# Epoch 1 Iteration 120
# 0.27940157
# Epoch 1 Iteration 121
# 0.18802865
# Epoch 1 Iteration 122
# 0.2257542
# Epoch 1 Iteration 123
# 0.17120023
# Epoch 1 Iteration 124
# 0.33351696
# Epoch 1 Iteration 125
# 0.4418636
# Epoch 1 Iteration 126
# 0.29025286
# Epoch 1 Iteration 127
# 0.17515093
# Epoch 1 Iteration 128
# 0.20772208
# Epoch 1 Iteration 129
# 0.16595758
# Epoch 1 Iteration 130
# 0.25329617
# Epoch 1 Iteration 131
# 0.25827342
# Epoch 1 Iteration 132
# 0.16556326
# Epoch 1 Iteration 133
# 0.3650739
# Epoch 1 Iteration 134
# 0.5012718
# Epoch 1 Iteration 135
# 0.32403687
# Epoch 1 Iteration 136
# 0.1804215
# Epoch 1 Iteration 137
# 0.17527512
# Epoch 1 Iteration 138
# 0.19413257
# Epoch 1 Iteration 139
# 0.18630911
# Epoch 1 Iteration 140
# 0.25994274
# Epoch 1 Iteration 141
# 0.30128047
# Epoch 1 Iteration 142
# 0.19096091
# Epoch 1 Iteration 143
# 0.26059154
# Epoch 1 Iteration 144
# 0.35821146
# Epoch 1 Iteration 145
# 0.24000119
# Epoch 1 Iteration 146
# 0.18770957
# Epoch 1 Iteration 147
# 0.21614102
# Epoch 1 Iteration 148
# 0.15990292
# Epoch 1 Iteration 149
# 0.33345512
# Epoch 1 Iteration 150
# 0.48613155
# Epoch 1 Iteration 151
# 0.3421551
# Epoch 1 Iteration 152
# 0.16239029
# Epoch 1 Iteration 153
# 0.36181659
# Epoch 1 Iteration 154
# 0.5403053
# Epoch 1 Iteration 155
# 0.42496893
# Epoch 1 Iteration 156
# 0.20726943
# Epoch 1 Iteration 157
# 0.460244
# Epoch 1 Iteration 158
# 0.83221936
# Epoch 1 Iteration 159
# 0.6808731
# Epoch 1 Iteration 160
# 0.2757154
# Epoch 1 Iteration 161
# 0.24992773
# Epoch 1 Iteration 162
# 0.3835359
# Epoch 1 Iteration 163
# 0.2153787
# Epoch 1 Iteration 164
# 0.3317461
# Epoch 1 Iteration 165
# 0.43670383
# Epoch 1 Iteration 166
# 0.18382022
# Epoch 1 Iteration 167
# 0.35609335
# Epoch 1 Iteration 168
# 0.58879
# Epoch 1 Iteration 169
# 0.4339776
# Epoch 1 Iteration 170
# 0.17358589
# Epoch 1 Iteration 171
# 0.4453376
# Epoch 1 Iteration 172
# 0.7612049
# Epoch 1 Iteration 173
# 0.5425767
# Epoch 1 Iteration 174
# 0.17699632
# Epoch 1 Iteration 175
# 0.6134332
# Epoch 1 Iteration 176
# 1.0559152
# Epoch 1 Iteration 177
# 0.6817635
# Epoch 1 Iteration 178
# 0.19683845
# Epoch 1 Iteration 179
# 0.5856457
# Epoch 1 Iteration 180
# 0.98042285
# Epoch 1 Iteration 181
# 0.5810901
# Epoch 1 Iteration 182
# 0.15558052
# Epoch 1 Iteration 183
# 0.71634185
# Epoch 1 Iteration 184
# 1.1757286
# Epoch 1 Iteration 185
# 0.68386644
# Epoch 1 Iteration 186
# 0.14711896
# Epoch 1 Iteration 187
# 0.8089184
# Epoch 1 Iteration 188
# 0.96081614
# Epoch 1 Iteration 189
# 0.3142593
# Epoch 1 Iteration 190
# 0.30806562
# Epoch 1 Iteration 191
# 0.533489
# Epoch 1 Iteration 192
# 0.28734103
# Epoch 1 Iteration 193
# 0.19538927
# Epoch 1 Iteration 194
# 0.26987782
# Epoch 1 Iteration 195
# 0.15184262
# Epoch 1 Iteration 196
# 0.35038537
# Epoch 1 Iteration 197
# 0.5291636
# Epoch 1 Iteration 198
# 0.3630423
# Epoch 1 Iteration 199
# 0.14379935
# Epoch 1 Iteration 200
# 0.5407863
# Epoch 1 Iteration 201
# 1.0017436
# Epoch 1 Iteration 202
# 0.8765105
# Epoch 1 Iteration 203
# 0.38368398
# Epoch 1 Iteration 204
# 0.1476127
# Epoch 1 Iteration 205
# 0.23716572
# Epoch 1 Iteration 206
# 0.19798273
# Epoch 1 Iteration 207
# 0.14490211
# Epoch 1 Iteration 208
# 0.1508247
# Epoch 1 Iteration 209
# 0.14294854
# Epoch 1 Iteration 210
# 0.13695323
# Epoch 1 Iteration 211
# 0.14979672
# Epoch 1 Iteration 212
# 0.13589478
# Epoch 1 Iteration 213
# 0.14685202
# Epoch 1 Iteration 214
# 0.13432272
# Epoch 1 Iteration 215
# 0.13433221
# Epoch 1 Iteration 216
# 0.14762315
# Epoch 1 Iteration 217
# 0.1330156
# Epoch 1 Iteration 218
# 0.164543
# Epoch 1 Iteration 219
# 0.14531471
# Epoch 1 Iteration 220
# 0.16212815
# Epoch 1 Iteration 221
# 0.17106074
# Epoch 1 Iteration 222
# 0.12970906
# Epoch 1 Iteration 223
# 0.14901851
# Epoch 1 Iteration 224
# 0.12960675
# Epoch 1 Iteration 225
# 0.1555448
# Epoch 1 Iteration 226
# 0.13712083
# Epoch 1 Iteration 227
# 0.16811152
# Epoch 1 Iteration 228
# 0.18053555
# Epoch 1 Iteration 229
# 0.12714043
# Epoch 1 Iteration 230
# 0.19543579
# Epoch 1 Iteration 231
# 0.21572992
# Epoch 1 Iteration 232
# 0.14069849
# Epoch 1 Iteration 233
# 0.20285317
# Epoch 1 Iteration 234
# 0.2852188
# Epoch 1 Iteration 235
# 0.20459273
# Epoch 1 Iteration 236
# 0.12660073
# Epoch 1 Iteration 237
# 0.14822775
# Epoch 1 Iteration 238
# 0.12635708
# Epoch 1 Iteration 239
# 0.19055444
# Epoch 1 Iteration 240
# 0.22682667
# Epoch 1 Iteration 241
# 0.14851356
# Epoch 1 Iteration 242
# 0.15918003
# Epoch 1 Iteration 243
# 0.21274725
# Epoch 1 Iteration 244
# 0.1602281
# Epoch 1 Iteration 245
# 0.13223353
# Epoch 1 Iteration 246
# 0.14976603
# Epoch 1 Iteration 247
# 0.121346876
# Epoch 1 Iteration 248
# 0.15956223
# Epoch 1 Iteration 249
# 0.15719467
# Epoch 1 Iteration 250
# 0.12008706
# Epoch 1 Iteration 251
# 0.14005628
# Epoch 1 Iteration 252
# 0.12168613
# Epoch 1 Iteration 253
# 0.17305738
# Epoch 1 Iteration 254
# 0.19977063
# Epoch 1 Iteration 255
# 0.13594869
# Epoch 1 Iteration 256
# 0.16232651
# Epoch 1 Iteration 257
# 0.21718517
# Epoch 1 Iteration 258
# 0.15836757
# Epoch 1 Iteration 259
# 0.12772533
# Epoch 1 Iteration 260
# 0.14476553
# Epoch 1 Iteration 261
# 0.117268026
# Epoch 1 Iteration 262
# 0.15693137
# Epoch 1 Iteration 263
# 0.15548456
# Epoch 1 Iteration 264
# 0.11619085
# Epoch 1 Iteration 265
# 0.13833565
# Epoch 1 Iteration 266
# 0.12100522
# Epoch 1 Iteration 267
# 0.15284756
# Epoch 1 Iteration 268
# 0.17008474
# Epoch 1 Iteration 269
# 0.11954619
# Epoch 1 Iteration 270
# 0.18739544
# Epoch 1 Iteration 271
# 0.25569686
# Epoch 1 Iteration 272
# 0.19138482
# Epoch 1 Iteration 273
# 0.113411546
# Epoch 1 Iteration 274
# 0.17237547
# Epoch 1 Iteration 275
# 0.17648058
# Epoch 1 Iteration 276
# 0.1156083
# Epoch 1 Iteration 277
# 0.21319589
# Epoch 1 Iteration 278
# 0.31881252
# Epoch 1 Iteration 279
# 0.2622229
# Epoch 1 Iteration 280
# 0.13046767
# Epoch 1 Iteration 281
# 0.19928657
# Epoch 1 Iteration 282
# 0.34971222
# Epoch 1 Iteration 283
# 0.3199827
# Epoch 1 Iteration 284
# 0.16300488
# Epoch 1 Iteration 285
# 0.1398983
# Epoch 1 Iteration 286
# 0.2161507
# Epoch 1 Iteration 287
# 0.18568984
# Epoch 1 Iteration 288
# 0.11153214
# Epoch 1 Iteration 289
# 0.21136421
# Epoch 1 Iteration 290
# 0.3014377
# Epoch 1 Iteration 291
# 0.22314155
# Epoch 1 Iteration 292
# 0.1115067
# Epoch 1 Iteration 293
# 0.2484631
# Epoch 1 Iteration 294
# 0.41642684
# Epoch 1 Iteration 295
# 0.39102197
# Epoch 1 Iteration 296
# 0.21427125
# Epoch 1 Iteration 297
# 0.11878555
# Epoch 1 Iteration 298
# 0.16956642
# Epoch 1 Iteration 299
# 0.146461
# Epoch 1 Iteration 300
# 0.110437244
# Epoch 2 Iteration 1
# 0.1173244
# Epoch 2 Iteration 2
# 0.11176367
# Epoch 2 Iteration 3
# 0.107549936
# Epoch 2 Iteration 4
# 0.10816622
# Epoch 2 Iteration 5
# 0.11102776
# Epoch 2 Iteration 6
# 0.108911395
# Epoch 2 Iteration 7
# 0.106466115
# Epoch 2 Iteration 8
# 0.10605736
# Epoch 2 Iteration 9
# 0.10699792
# Epoch 2 Iteration 10
# 0.10768759
# Epoch 2 Iteration 11
# 0.108509056
# Epoch 2 Iteration 12
# 0.10585068
# Epoch 2 Iteration 13
# 0.1044215
# Epoch 2 Iteration 14
# 0.10372978
# Epoch 2 Iteration 15
# 0.10420288
# Epoch 2 Iteration 16
# 0.10578759
# Epoch 2 Iteration 17
# 0.10686247
# Epoch 2 Iteration 18
# 0.10430631
# Epoch 2 Iteration 19
# 0.102652356
# Epoch 2 Iteration 20
# 0.10174441
# Epoch 2 Iteration 21
# 0.10091124
# Epoch 2 Iteration 22
# 0.100170106
# Epoch 2 Iteration 23
# 0.09978525
# Epoch 2 Iteration 24
# 0.099592164
# Epoch 2 Iteration 25
# 0.09935425
# Epoch 2 Iteration 26
# 0.099295616
# Epoch 2 Iteration 27
# 0.099821165
# Epoch 2 Iteration 28
# 0.10099329
# Epoch 2 Iteration 29
# 0.1020768
# Epoch 2 Iteration 30
# 0.09841129
# Epoch 2 Iteration 31
# 0.096882805
# Epoch 2 Iteration 32
# 0.09611328
# Epoch 2 Iteration 33
# 0.0956441
# Epoch 2 Iteration 34
# 0.0954559
# Epoch 2 Iteration 35
# 0.09566504
# Epoch 2 Iteration 36
# 0.096769094
# Epoch 2 Iteration 37
# 0.100195885
# Epoch 2 Iteration 38
# 0.09547557
# Epoch 2 Iteration 39
# 0.0937739
# Epoch 2 Iteration 40
# 0.09299892
# Epoch 2 Iteration 41
# 0.09249145
# Epoch 2 Iteration 42
# 0.092065595
# Epoch 2 Iteration 43
# 0.09166023
# Epoch 2 Iteration 44
# 0.09131633
# Epoch 2 Iteration 45
# 0.09123493
# Epoch 2 Iteration 46
# 0.09228768
# Epoch 2 Iteration 47
# 0.09848992
# Epoch 2 Iteration 48
# 0.09182286
# Epoch 2 Iteration 49
# 0.09065999
# Epoch 2 Iteration 50
# 0.09228465
# Epoch 2 Iteration 51
# 0.09809621
# Epoch 2 Iteration 52
# 0.088068664
# Epoch 2 Iteration 53
# 0.08951761
# Epoch 2 Iteration 54
# 0.10191099
# Epoch 2 Iteration 55
# 0.08719367
# Epoch 2 Iteration 56
# 0.112574086
# Epoch 2 Iteration 57
# 0.09586204
# Epoch 2 Iteration 58
# 0.12212621
# Epoch 2 Iteration 59
# 0.12981236
# Epoch 2 Iteration 60
# 0.0860067
# Epoch 2 Iteration 61
# 0.108186916
# Epoch 2 Iteration 62
# 0.10131411
# Epoch 2 Iteration 63
# 0.097927004
# Epoch 2 Iteration 64
# 0.15316097
# Epoch 2 Iteration 65
# 0.15067744
# Epoch 2 Iteration 66
# 0.10002869
# Epoch 2 Iteration 67
# 0.099301845
# Epoch 2 Iteration 68
# 0.12716499
# Epoch 2 Iteration 69
# 0.11897963
# Epoch 2 Iteration 70
# 0.101823285
# Epoch 2 Iteration 71
# 0.09609551
# Epoch 2 Iteration 72
# 0.1270368
# Epoch 2 Iteration 73
# 0.12600684
# Epoch 2 Iteration 74
# 0.09071143
# Epoch 2 Iteration 75
# 0.08927197
# Epoch 2 Iteration 76
# 0.11396171
# Epoch 2 Iteration 77
# 0.10160311
# Epoch 2 Iteration 78
# 0.10543312
# Epoch 2 Iteration 79
# 0.10621789
# Epoch 2 Iteration 80
# 0.09227006
# Epoch 2 Iteration 81
# 0.08955987
# Epoch 2 Iteration 82
# 0.11192107
# Epoch 2 Iteration 83
# 0.1089913
# Epoch 2 Iteration 84
# 0.08972502
# Epoch 2 Iteration 85
# 0.08550834
# Epoch 2 Iteration 86
# 0.09750482
# Epoch 2 Iteration 87
# 0.0858779
# Epoch 2 Iteration 88
# 0.10972707
# Epoch 2 Iteration 89
# 0.099870615
# Epoch 2 Iteration 90
# 0.09527799
# Epoch 2 Iteration 91
# 0.0954725
# Epoch 2 Iteration 92
# 0.09176607
# Epoch 2 Iteration 93
# 0.08682142
# Epoch 2 Iteration 94
# 0.11312182
# Epoch 2 Iteration 95
# 0.11668445
# Epoch 2 Iteration 96
# 0.08281565
# Epoch 2 Iteration 97
# 0.10899148
# Epoch 2 Iteration 98
# 0.09359425
# Epoch 2 Iteration 99
# 0.10249172
# Epoch 2 Iteration 100
# 0.11053073
# Epoch 2 Iteration 101
# 0.08206271
# Epoch 2 Iteration 102
# 0.104417115
# Epoch 2 Iteration 103
# 0.08851524
# Epoch 2 Iteration 104
# 0.11862013
# Epoch 2 Iteration 105
# 0.14060976
# Epoch 2 Iteration 106
# 0.09282419
# Epoch 2 Iteration 107
# 0.14915943
# Epoch 2 Iteration 108
# 0.22794831
# Epoch 2 Iteration 109
# 0.17111108
# Epoch 2 Iteration 110
# 0.09392212
# Epoch 2 Iteration 111
# 0.1216571
# Epoch 2 Iteration 112
# 0.13827096
# Epoch 2 Iteration 113
# 0.13474444
# Epoch 2 Iteration 114
# 0.109521486
# Epoch 2 Iteration 115
# 0.087227166
# Epoch 2 Iteration 116
# 0.09803464
# Epoch 2 Iteration 117
# 0.09993484
# Epoch 2 Iteration 118
# 0.107582755
# Epoch 2 Iteration 119
# 0.100373164
# Epoch 2 Iteration 120
# 0.08681614
# Epoch 2 Iteration 121
# 0.10097508
# Epoch 2 Iteration 122
# 0.10471026
# Epoch 2 Iteration 123
# 0.09163554
# Epoch 2 Iteration 124
# 0.086920656
# Epoch 2 Iteration 125
# 0.09999776
# Epoch 2 Iteration 126
# 0.09598147
# Epoch 2 Iteration 127
# 0.095821396
# Epoch 2 Iteration 128
# 0.09454704
# Epoch 2 Iteration 129
# 0.08572153
# Epoch 2 Iteration 130
# 0.08461568
# Epoch 2 Iteration 131
# 0.09351003
# Epoch 2 Iteration 132
# 0.08804632
# Epoch 2 Iteration 133
# 0.09382666
# Epoch 2 Iteration 134
# 0.09075378
# Epoch 2 Iteration 135
# 0.089923725
# Epoch 2 Iteration 136
# 0.08839212
# Epoch 2 Iteration 137
# 0.08696546
# Epoch 2 Iteration 138
# 0.08616897
# Epoch 2 Iteration 139
# 0.08859594
# Epoch 2 Iteration 140
# 0.08470987
# Epoch 2 Iteration 141
# 0.08959682
# Epoch 2 Iteration 142
# 0.086556405
# Epoch 2 Iteration 143
# 0.08919929
# Epoch 2 Iteration 144
# 0.08808381
# Epoch 2 Iteration 145
# 0.08366926
# Epoch 2 Iteration 146
# 0.08228528
# Epoch 2 Iteration 147
# 0.088540375
# Epoch 2 Iteration 148
# 0.08556531
# Epoch 2 Iteration 149
# 0.08538242
# Epoch 2 Iteration 150
# 0.081641674
# Epoch 2 Iteration 151
# 0.09143948
# Epoch 2 Iteration 152
# 0.091537684
# Epoch 2 Iteration 153
# 0.07913606
# Epoch 2 Iteration 154
# 0.077645
# Epoch 2 Iteration 155
# 0.08732109
# Epoch 2 Iteration 156
# 0.08151255
# Epoch 2 Iteration 157
# 0.091634154
# Epoch 2 Iteration 158
# 0.08959323
# Epoch 2 Iteration 159
# 0.07900462
# Epoch 2 Iteration 160
# 0.07640904
# Epoch 2 Iteration 161
# 0.08499186
# Epoch 2 Iteration 162
# 0.07672394
# Epoch 2 Iteration 163
# 0.09613584
# Epoch 2 Iteration 164
# 0.09628809
# Epoch 2 Iteration 165
# 0.07441904
# Epoch 2 Iteration 166
# 0.085424006
# Epoch 2 Iteration 167
# 0.07316868
# Epoch 2 Iteration 168
# 0.0836121
# Epoch 2 Iteration 169
# 0.07350066
# Epoch 2 Iteration 170
# 0.086262845
# Epoch 2 Iteration 171
# 0.07531665
# Epoch 2 Iteration 172
# 0.09710619
# Epoch 2 Iteration 173
# 0.09961264
# Epoch 2 Iteration 174
# 0.072336346
# Epoch 2 Iteration 175
# 0.0926528
# Epoch 2 Iteration 176
# 0.07835992
# Epoch 2 Iteration 177
# 0.09849818
# Epoch 2 Iteration 178
# 0.113202594
# Epoch 2 Iteration 179
# 0.07596007
# Epoch 2 Iteration 180
# 0.13230194
# Epoch 2 Iteration 181
# 0.19185631
# Epoch 2 Iteration 182
# 0.1337629
# Epoch 2 Iteration 183
# 0.07144658
# Epoch 2 Iteration 184
# 0.1128498
# Epoch 2 Iteration 185
# 0.110370845
# Epoch 2 Iteration 186
# 0.07095468
# Epoch 2 Iteration 187
# 0.110869564
# Epoch 2 Iteration 188
# 0.116907164
# Epoch 2 Iteration 189
# 0.07297486
# Epoch 2 Iteration 190
# 0.12392775
# Epoch 2 Iteration 191
# 0.16535038
# Epoch 2 Iteration 192
# 0.11291127
# Epoch 2 Iteration 193
# 0.07357697
# Epoch 2 Iteration 194
# 0.08494339
# Epoch 2 Iteration 195
# 0.071037516
# Epoch 2 Iteration 196
# 0.08220376
# Epoch 2 Iteration 197
# 0.070245355
# Epoch 2 Iteration 198
# 0.08882233
# Epoch 2 Iteration 199
# 0.07817142
# Epoch 2 Iteration 200
# 0.08344619
# Epoch 2 Iteration 201
# 0.08919639
# Epoch 2 Iteration 202
# 0.069210544
# Epoch 2 Iteration 203
# 0.07767596
# Epoch 2 Iteration 204
# 0.07120093
# Epoch 2 Iteration 205
# 0.068704575
# Epoch 2 Iteration 206
# 0.07630376
# Epoch 2 Iteration 207
# 0.0687508
# Epoch 2 Iteration 208
# 0.07488118
# Epoch 2 Iteration 209
# 0.07009193
# Epoch 2 Iteration 210
# 0.07415373
# Epoch 2 Iteration 211
# 0.06585953
# Epoch 2 Iteration 212
# 0.074582726
# Epoch 2 Iteration 213
# 0.06505949
# Epoch 2 Iteration 214
# 0.06628217
# Epoch 2 Iteration 215
# 0.07068193
# Epoch 2 Iteration 216
# 0.06450411
# Epoch 2 Iteration 217
# 0.07296646
# Epoch 2 Iteration 218
# 0.06356473
# Epoch 2 Iteration 219
# 0.07894627
# Epoch 2 Iteration 220
# 0.06996844
# Epoch 2 Iteration 221
# 0.079162575
# Epoch 2 Iteration 222
# 0.07703701
# Epoch 2 Iteration 223
# 0.06617865
# Epoch 2 Iteration 224
# 0.061725125
# Epoch 2 Iteration 225
# 0.07224307
# Epoch 2 Iteration 226
# 0.06174899
# Epoch 2 Iteration 227
# 0.07895921
# Epoch 2 Iteration 228
# 0.06936523
# Epoch 2 Iteration 229
# 0.078619614
# Epoch 2 Iteration 230
# 0.077735126
# Epoch 2 Iteration 231
# 0.06444247
# Epoch 2 Iteration 232
# 0.062327642
# Epoch 2 Iteration 233
# 0.072198465
# Epoch 2 Iteration 234
# 0.06662388
# Epoch 2 Iteration 235
# 0.08263907
# Epoch 2 Iteration 236
# 0.080644764
# Epoch 2 Iteration 237
# 0.07559286
# Epoch 2 Iteration 238
# 0.070626765
# Epoch 2 Iteration 239
# 0.08331625
# Epoch 2 Iteration 240
# 0.078654
# Epoch 2 Iteration 241
# 0.07177259
# Epoch 2 Iteration 242
# 0.067450635
# Epoch 2 Iteration 243
# 0.10741968
# Epoch 2 Iteration 244
# 0.08337322
# Epoch 2 Iteration 245
# 0.08022309
# Epoch 2 Iteration 246
# 0.0746973
# Epoch 2 Iteration 247
# 0.10268906
# Epoch 2 Iteration 248
# 0.096334696
# Epoch 2 Iteration 249
# 0.07362973
# Epoch 2 Iteration 250
# 0.07300951
# Epoch 2 Iteration 251
# 0.08856201
# Epoch 2 Iteration 252
# 0.0843748
# Epoch 2 Iteration 253
# 0.075294696
# Epoch 2 Iteration 254
# 0.071646646
# Epoch 2 Iteration 255
# 0.089580745
# Epoch 2 Iteration 256
# 0.08945647
# Epoch 2 Iteration 257
# 0.068785205
# Epoch 2 Iteration 258
# 0.073533796
# Epoch 2 Iteration 259
# 0.06963388
# Epoch 2 Iteration 260
# 0.06601909
# Epoch 2 Iteration 261
# 0.07071641
# Epoch 2 Iteration 262
# 0.06697885
# Epoch 2 Iteration 263
# 0.06589952
# Epoch 2 Iteration 264
# 0.06877416
# Epoch 2 Iteration 265
# 0.06574822
# Epoch 2 Iteration 266
# 0.065293245
# Epoch 2 Iteration 267
# 0.06710929
# Epoch 2 Iteration 268
# 0.064769566
# Epoch 2 Iteration 269
# 0.06465327
# Epoch 2 Iteration 270
# 0.06581715
# Epoch 2 Iteration 271
# 0.06400716
# Epoch 2 Iteration 272
# 0.06380044
# Epoch 2 Iteration 273
# 0.06465763
# Epoch 2 Iteration 274
# 0.06341264
# Epoch 2 Iteration 275
# 0.06285726
# Epoch 2 Iteration 276
# 0.06354269
# Epoch 2 Iteration 277
# 0.06283669
# Epoch 2 Iteration 278
# 0.061783463
# Epoch 2 Iteration 279
# 0.062081702
# Epoch 2 Iteration 280
# 0.06211657
# Epoch 2 Iteration 281
# 0.060995784
# Epoch 2 Iteration 282
# 0.06029647
# Epoch 2 Iteration 283
# 0.060342014
# Epoch 2 Iteration 284
# 0.06028176
# Epoch 2 Iteration 285
# 0.059905484
# Epoch 2 Iteration 286
# 0.05933918
# Epoch 2 Iteration 287
# 0.059141066
# Epoch 2 Iteration 288
# 0.059720725
# Epoch 2 Iteration 289
# 0.063829094
# Epoch 2 Iteration 290
# 0.057882592
# Epoch 2 Iteration 291
# 0.055820905
# Epoch 2 Iteration 292
# 0.054645076
# Epoch 2 Iteration 293
# 0.05428662
# Epoch 2 Iteration 294
# 0.05435113
# Epoch 2 Iteration 295
# 0.055037133
# Epoch 2 Iteration 296
# 0.05890447
# Epoch 2 Iteration 297
# 0.05483512
# Epoch 2 Iteration 298
# 0.054111354
# Epoch 2 Iteration 299
# 0.053798124
# Epoch 2 Iteration 300
# 0.05431307
# Epoch 3 Iteration 1
# 0.053998794
# Epoch 3 Iteration 2
# 0.05372058
# Epoch 3 Iteration 3
# 0.052084714
# Epoch 3 Iteration 4
# 0.05027628
# Epoch 3 Iteration 5
# 0.0493363
# Epoch 3 Iteration 6
# 0.04908168
# Epoch 3 Iteration 7
# 0.049374387
# Epoch 3 Iteration 8
# 0.049843535
# Epoch 3 Iteration 9
# 0.051125374
# Epoch 3 Iteration 10
# 0.050750747
# Epoch 3 Iteration 11
# 0.050093286
# Epoch 3 Iteration 12
# 0.04828342
# Epoch 3 Iteration 13
# 0.04725311
# Epoch 3 Iteration 14
# 0.048231713
# Epoch 3 Iteration 15
# 0.049266875
# Epoch 3 Iteration 16
# 0.050292857
# Epoch 3 Iteration 17
# 0.051166877
# Epoch 3 Iteration 18
# 0.05287138
# Epoch 3 Iteration 19
# 0.04891049
# Epoch 3 Iteration 20
# 0.05072751
# Epoch 3 Iteration 21
# 0.054222032
# Epoch 3 Iteration 22
# 0.056047954
# Epoch 3 Iteration 23
# 0.05450283
# Epoch 3 Iteration 24
# 0.056304254
# Epoch 3 Iteration 25
# 0.05407078
# Epoch 3 Iteration 26
# 0.05159106
# Epoch 3 Iteration 27
# 0.053316846
# Epoch 3 Iteration 28
# 0.053159617
# Epoch 3 Iteration 29
# 0.05113551
# Epoch 3 Iteration 30
# 0.0505941
# Epoch 3 Iteration 31
# 0.05074749
# Epoch 3 Iteration 32
# 0.04827825
# Epoch 3 Iteration 33
# 0.050629143
# Epoch 3 Iteration 34
# 0.05029196
# Epoch 3 Iteration 35
# 0.048881233
# Epoch 3 Iteration 36
# 0.049919784
# Epoch 3 Iteration 37
# 0.05070766
# Epoch 3 Iteration 38
# 0.049278855
# Epoch 3 Iteration 39
# 0.04813526
# Epoch 3 Iteration 40
# 0.04844731
# Epoch 3 Iteration 41
# 0.046353914
# Epoch 3 Iteration 42
# 0.045688536
# Epoch 3 Iteration 43
# 0.04620226
# Epoch 3 Iteration 44
# 0.045145303
# Epoch 3 Iteration 45
# 0.046088293
# Epoch 3 Iteration 46
# 0.045882836
# Epoch 3 Iteration 47
# 0.046289593
# Epoch 3 Iteration 48
# 0.050596856
# Epoch 3 Iteration 49
# 0.04923947
# Epoch 3 Iteration 50
# 0.048773058
# Epoch 3 Iteration 51
# 0.046607494
# Epoch 3 Iteration 52
# 0.043882817
# Epoch 3 Iteration 53
# 0.04593029
# Epoch 3 Iteration 54
# 0.04712083
# Epoch 3 Iteration 55
# 0.046706177
# Epoch 3 Iteration 56
# 0.045143876
# Epoch 3 Iteration 57
# 0.04324185
# Epoch 3 Iteration 58
# 0.044545524
# Epoch 3 Iteration 59
# 0.044866074
# Epoch 3 Iteration 60
# 0.044822246
# Epoch 3 Iteration 61
# 0.043781973
# Epoch 3 Iteration 62
# 0.042971525
# Epoch 3 Iteration 63
# 0.042662125
# Epoch 3 Iteration 64
# 0.042516813
# Epoch 3 Iteration 65
# 0.043384157
# Epoch 3 Iteration 66
# 0.046925373
# Epoch 3 Iteration 67
# 0.04414857
# Epoch 3 Iteration 68
# 0.043391205
# Epoch 3 Iteration 69
# 0.04287618
# Epoch 3 Iteration 70
# 0.041900747
# Epoch 3 Iteration 71
# 0.04224913
# Epoch 3 Iteration 72
# 0.043150753
# Epoch 3 Iteration 73
# 0.044160932
# Epoch 3 Iteration 74
# 0.04405842
# Epoch 3 Iteration 75
# 0.04260674
# Epoch 3 Iteration 76
# 0.04105016
# Epoch 3 Iteration 77
# 0.041285265
# Epoch 3 Iteration 78
# 0.04220736
# Epoch 3 Iteration 79
# 0.043321133
# Epoch 3 Iteration 80
# 0.04587981
# Epoch 3 Iteration 81
# 0.04609318
# Epoch 3 Iteration 82
# 0.045689046
# Epoch 3 Iteration 83
# 0.04118994
# Epoch 3 Iteration 84
# 0.045011062
# Epoch 3 Iteration 85
# 0.047896676
# Epoch 3 Iteration 86
# 0.04543048
# Epoch 3 Iteration 87
# 0.047758155
# Epoch 3 Iteration 88
# 0.044710316
# Epoch 3 Iteration 89
# 0.044405654
# Epoch 3 Iteration 90
# 0.045794643
# Epoch 3 Iteration 91
# 0.044150997
# Epoch 3 Iteration 92
# 0.04722344
# Epoch 3 Iteration 93
# 0.045338854
# Epoch 3 Iteration 94
# 0.043278553
# Epoch 3 Iteration 95
# 0.0417931
# Epoch 3 Iteration 96
# 0.041844457
# Epoch 3 Iteration 97
# 0.044592112
# Epoch 3 Iteration 98
# 0.04550995
# Epoch 3 Iteration 99
# 0.044318613
# Epoch 3 Iteration 100
# 0.04192942
# Epoch 3 Iteration 101
# 0.040439703
# Epoch 3 Iteration 102
# 0.042295795
# Epoch 3 Iteration 103
# 0.042868182
# Epoch 3 Iteration 104
# 0.04538283
# Epoch 3 Iteration 105
# 0.048007723
# Epoch 3 Iteration 106
# 0.04292358
# Epoch 3 Iteration 107
# 0.043184903
# Epoch 3 Iteration 108
# 0.044588264
# Epoch 3 Iteration 109
# 0.045114044
# Epoch 3 Iteration 110
# 0.041145682
# Epoch 3 Iteration 111
# 0.041129086
# Epoch 3 Iteration 112
# 0.040584393
# Epoch 3 Iteration 113
# 0.04193763
# Epoch 3 Iteration 114
# 0.040207073
# Epoch 3 Iteration 115
# 0.04026491
# Epoch 3 Iteration 116
# 0.04039166
# Epoch 3 Iteration 117
# 0.04143841
# Epoch 3 Iteration 118
# 0.040696904
# Epoch 3 Iteration 119
# 0.04066727
# Epoch 3 Iteration 120
# 0.040193338
# Epoch 3 Iteration 121
# 0.038839
# Epoch 3 Iteration 122
# 0.03966199
# Epoch 3 Iteration 123
# 0.03993315
# Epoch 3 Iteration 124
# 0.04110367
# Epoch 3 Iteration 125
# 0.04380607
# Epoch 3 Iteration 126
# 0.046529174
# Epoch 3 Iteration 127
# 0.03953358
# Epoch 3 Iteration 128
# 0.039855246
# Epoch 3 Iteration 129
# 0.04587482
# Epoch 3 Iteration 130
# 0.04091492
# Epoch 3 Iteration 131
# 0.03813152
# Epoch 3 Iteration 132
# 0.039452154
# Epoch 3 Iteration 133
# 0.041372396
# Epoch 3 Iteration 134
# 0.042130552
# Epoch 3 Iteration 135
# 0.03981544
# Epoch 3 Iteration 136
# 0.038152717
# Epoch 3 Iteration 137
# 0.038358808
# Epoch 3 Iteration 138
# 0.03947643
# Epoch 3 Iteration 139
# 0.04127739
# Epoch 3 Iteration 140
# 0.040916942
# Epoch 3 Iteration 141
# 0.039547905
# Epoch 3 Iteration 142
# 0.03791655
# Epoch 3 Iteration 143
# 0.0370024
# Epoch 3 Iteration 144
# 0.037617747
# Epoch 3 Iteration 145
# 0.03805327
# Epoch 3 Iteration 146
# 0.038328726
# Epoch 3 Iteration 147
# 0.037839822
# Epoch 3 Iteration 148
# 0.03733521
# Epoch 3 Iteration 149
# 0.03849182
# Epoch 3 Iteration 150
# 0.042068973
# Epoch 3 Iteration 151
# 0.042444866
# Epoch 3 Iteration 152
# 0.03978672
# Epoch 3 Iteration 153
# 0.046802096
# Epoch 3 Iteration 154
# 0.046235304
# Epoch 3 Iteration 155
# 0.04678488
# Epoch 3 Iteration 156
# 0.043904174
# Epoch 3 Iteration 157
# 0.046492368
# Epoch 3 Iteration 158
# 0.042980105
# Epoch 3 Iteration 159
# 0.042264685
# Epoch 3 Iteration 160
# 0.043905903
# Epoch 3 Iteration 161
# 0.045001086
# Epoch 3 Iteration 162
# 0.05199983
# Epoch 3 Iteration 163
# 0.044502176
# Epoch 3 Iteration 164
# 0.04456609
# Epoch 3 Iteration 165
# 0.050851464
# Epoch 3 Iteration 166
# 0.043519244
# Epoch 3 Iteration 167
# 0.040563527
# Epoch 3 Iteration 168
# 0.041545868
# Epoch 3 Iteration 169
# 0.045435965
# Epoch 3 Iteration 170
# 0.041914128
# Epoch 3 Iteration 171
# 0.038446456
# Epoch 3 Iteration 172
# 0.040642362
# Epoch 3 Iteration 173
# 0.041217178
# Epoch 3 Iteration 174
# 0.04033289
# Epoch 3 Iteration 175
# 0.03790076
# Epoch 3 Iteration 176
# 0.037476033
# Epoch 3 Iteration 177
# 0.03766954
# Epoch 3 Iteration 178
# 0.040032536
# Epoch 3 Iteration 179
# 0.045307178
# Epoch 3 Iteration 180
# 0.050371017
# Epoch 3 Iteration 181
# 0.04182209
# Epoch 3 Iteration 182
# 0.05458752
# Epoch 3 Iteration 183
# 0.04268103
# Epoch 3 Iteration 184
# 0.07358403
# Epoch 3 Iteration 185
# 0.06886364
# Epoch 3 Iteration 186
# 0.050051067
# Epoch 3 Iteration 187
# 0.04149674
# Epoch 3 Iteration 188
# 0.057329647
# Epoch 3 Iteration 189
# 0.04009515
# Epoch 3 Iteration 190
# 0.0441033
# Epoch 3 Iteration 191
# 0.050381668
# Epoch 3 Iteration 192
# 0.04327389
# Epoch 3 Iteration 193
# 0.048536584
# Epoch 3 Iteration 194
# 0.041147463
# Epoch 3 Iteration 195
# 0.043878853
# Epoch 3 Iteration 196
# 0.046021815
# Epoch 3 Iteration 197
# 0.040206492
# Epoch 3 Iteration 198
# 0.05062466
# Epoch 3 Iteration 199
# 0.038405143
# Epoch 3 Iteration 200
# 0.045883276
# Epoch 3 Iteration 201
# 0.040954165
# Epoch 3 Iteration 202
# 0.037870165
# Epoch 3 Iteration 203
# 0.04173042
# Epoch 3 Iteration 204
# 0.04079783
# Epoch 3 Iteration 205
# 0.037013475
# Epoch 3 Iteration 206
# 0.03795751
# Epoch 3 Iteration 207
# 0.03930758
# Epoch 3 Iteration 208
# 0.040780198
# Epoch 3 Iteration 209
# 0.041338876
# Epoch 3 Iteration 210
# 0.03775677
# Epoch 3 Iteration 211
# 0.03661298
# Epoch 3 Iteration 212
# 0.038841475
# Epoch 3 Iteration 213
# 0.038345307
# Epoch 3 Iteration 214
# 0.036680702
# Epoch 3 Iteration 215
# 0.03618173
# Epoch 3 Iteration 216
# 0.03723144
# Epoch 3 Iteration 217
# 0.036785036
# Epoch 3 Iteration 218
# 0.03502257
# Epoch 3 Iteration 219
# 0.036185037
# Epoch 3 Iteration 220
# 0.036702663
# Epoch 3 Iteration 221
# 0.035798624
# Epoch 3 Iteration 222
# 0.034848537
# Epoch 3 Iteration 223
# 0.034762308
# Epoch 3 Iteration 224
# 0.035658933
# Epoch 3 Iteration 225
# 0.03518167
# Epoch 3 Iteration 226
# 0.034611993
# Epoch 3 Iteration 227
# 0.03380192
# Epoch 3 Iteration 228
# 0.03421562
# Epoch 3 Iteration 229
# 0.034287486
# Epoch 3 Iteration 230
# 0.034619145
# Epoch 3 Iteration 231
# 0.035200413
# Epoch 3 Iteration 232
# 0.036700882
# Epoch 3 Iteration 233
# 0.035175867
# Epoch 3 Iteration 234
# 0.03438597
# Epoch 3 Iteration 235
# 0.03392813
# Epoch 3 Iteration 236
# 0.034737043
# Epoch 3 Iteration 237
# 0.035048027
# Epoch 3 Iteration 238
# 0.035282806
# Epoch 3 Iteration 239
# 0.03533094
# Epoch 3 Iteration 240
# 0.033807922
# Epoch 3 Iteration 241
# 0.03312601
# Epoch 3 Iteration 242
# 0.03412168
# Epoch 3 Iteration 243
# 0.034596503
# Epoch 3 Iteration 244
# 0.03419554
# Epoch 3 Iteration 245
# 0.03351661
# Epoch 3 Iteration 246
# 0.034075007
# Epoch 3 Iteration 247
# 0.03620861
# Epoch 3 Iteration 248
# 0.04293878
# Epoch 3 Iteration 249
# 0.04522647
# Epoch 3 Iteration 250
# 0.039883412
# Epoch 3 Iteration 251
# 0.037690006
# Epoch 3 Iteration 252
# 0.04528688
# Epoch 3 Iteration 253
# 0.03720929
# Epoch 3 Iteration 254
# 0.03925458
# Epoch 3 Iteration 255
# 0.03865543
# Epoch 3 Iteration 256
# 0.042967476
# Epoch 3 Iteration 257
# 0.03857608
# Epoch 3 Iteration 258
# 0.03509371
# Epoch 3 Iteration 259
# 0.0366184
# Epoch 3 Iteration 260
# 0.03961139
# Epoch 3 Iteration 261
# 0.038203083
# Epoch 3 Iteration 262
# 0.037170462
# Epoch 3 Iteration 263
# 0.03495242
# Epoch 3 Iteration 264
# 0.035507552
# Epoch 3 Iteration 265
# 0.034169372
# Epoch 3 Iteration 266
# 0.034404106
# Epoch 3 Iteration 267
# 0.034408674
# Epoch 3 Iteration 268
# 0.034009036
# Epoch 3 Iteration 269
# 0.0338671
# Epoch 3 Iteration 270
# 0.03325574
# Epoch 3 Iteration 271
# 0.03343945
# Epoch 3 Iteration 272
# 0.033557788
# Epoch 3 Iteration 273
# 0.03347818
# Epoch 3 Iteration 274
# 0.032767326
# Epoch 3 Iteration 275
# 0.03229653
# Epoch 3 Iteration 276
# 0.031990346
# Epoch 3 Iteration 277
# 0.032144412
# Epoch 3 Iteration 278
# 0.032421213
# Epoch 3 Iteration 279
# 0.033275876
# Epoch 3 Iteration 280
# 0.034361564
# Epoch 3 Iteration 281
# 0.036909506
# Epoch 3 Iteration 282
# 0.040268943
# Epoch 3 Iteration 283
# 0.038460046
# Epoch 3 Iteration 284
# 0.034504965
# Epoch 3 Iteration 285
# 0.033322416
# Epoch 3 Iteration 286
# 0.038404383
# Epoch 3 Iteration 287
# 0.041919954
# Epoch 3 Iteration 288
# 0.040361214
# Epoch 3 Iteration 289
# 0.03596695
# Epoch 3 Iteration 290
# 0.037518863
# Epoch 3 Iteration 291
# 0.038782656
# Epoch 3 Iteration 292
# 0.038777363
# Epoch 3 Iteration 293
# 0.03627003
# Epoch 3 Iteration 294
# 0.035042293
# Epoch 3 Iteration 295
# 0.033413183
# Epoch 3 Iteration 296
# 0.03457608
# Epoch 3 Iteration 297
# 0.033985153
# Epoch 3 Iteration 298
# 0.033479694
# Epoch 3 Iteration 299
# 0.03317324
# Epoch 3 Iteration 300
# 0.032128833
# Epoch 4 Iteration 1
# 0.032278217
# Epoch 4 Iteration 2
# 0.032634515
# Epoch 4 Iteration 3
# 0.032185927
# Epoch 4 Iteration 4
# 0.031792395
# Epoch 4 Iteration 5
# 0.03094906
# Epoch 4 Iteration 6
# 0.031379994
# Epoch 4 Iteration 7
# 0.031110307
# Epoch 4 Iteration 8
# 0.031723067
# Epoch 4 Iteration 9
# 0.033139765
# Epoch 4 Iteration 10
# 0.033933926
# Epoch 4 Iteration 11
# 0.032942727
# Epoch 4 Iteration 12
# 0.03216005
# Epoch 4 Iteration 13
# 0.031003674
# Epoch 4 Iteration 14
# 0.032329675
# Epoch 4 Iteration 15
# 0.033309065
# Epoch 4 Iteration 16
# 0.032147165
# Epoch 4 Iteration 17
# 0.030718496
# Epoch 4 Iteration 18
# 0.030575182
# Epoch 4 Iteration 19
# 0.03177791
# Epoch 4 Iteration 20
# 0.032576997
# Epoch 4 Iteration 21
# 0.031082066
# Epoch 4 Iteration 22
# 0.03187178
# Epoch 4 Iteration 23
# 0.03199245
# Epoch 4 Iteration 24
# 0.030493304
# Epoch 4 Iteration 25
# 0.030857772
# Epoch 4 Iteration 26
# 0.031769775
# Epoch 4 Iteration 27
# 0.031381674
# Epoch 4 Iteration 28
# 0.030909367
# Epoch 4 Iteration 29
# 0.030777436
# Epoch 4 Iteration 30
# 0.031709492
# Epoch 4 Iteration 31
# 0.03124271
# Epoch 4 Iteration 32
# 0.030292083
# Epoch 4 Iteration 33
# 0.030864222
# Epoch 4 Iteration 34
# 0.029853003
# Epoch 4 Iteration 35
# 0.029161308
# Epoch 4 Iteration 36
# 0.02955401
# Epoch 4 Iteration 37
# 0.030345403
# Epoch 4 Iteration 38
# 0.031426247
# Epoch 4 Iteration 39
# 0.032719865
# Epoch 4 Iteration 40
# 0.030575862
# Epoch 4 Iteration 41
# 0.032975655
# Epoch 4 Iteration 42
# 0.03195247
# Epoch 4 Iteration 43
# 0.03056532
# Epoch 4 Iteration 44
# 0.032568857
# Epoch 4 Iteration 45
# 0.031867843
# Epoch 4 Iteration 46
# 0.03145372
# Epoch 4 Iteration 47
# 0.030664332
# Epoch 4 Iteration 48
# 0.030309264
# Epoch 4 Iteration 49
# 0.030471638
# Epoch 4 Iteration 50
# 0.030417252
# Epoch 4 Iteration 51
# 0.02994835
# Epoch 4 Iteration 52
# 0.029933747
# Epoch 4 Iteration 53
# 0.030241769
# Epoch 4 Iteration 54
# 0.028803043
# Epoch 4 Iteration 55
# 0.03106818
# Epoch 4 Iteration 56
# 0.035341926
# Epoch 4 Iteration 57
# 0.047615565
# Epoch 4 Iteration 58
# 0.037131563
# Epoch 4 Iteration 59
# 0.035548247
# Epoch 4 Iteration 60
# 0.042901766
# Epoch 4 Iteration 61
# 0.03650408
# Epoch 4 Iteration 62
# 0.035859548
# Epoch 4 Iteration 63
# 0.033839643
# Epoch 4 Iteration 64
# 0.03197316
# Epoch 4 Iteration 65
# 0.032867834
# Epoch 4 Iteration 66
# 0.03245105
# Epoch 4 Iteration 67
# 0.031577736
# Epoch 4 Iteration 68
# 0.03196224
# Epoch 4 Iteration 69
# 0.03145005
# Epoch 4 Iteration 70
# 0.031626217
# Epoch 4 Iteration 71
# 0.029858444
# Epoch 4 Iteration 72
# 0.030411087
# Epoch 4 Iteration 73
# 0.029730689
# Epoch 4 Iteration 74
# 0.030285848
# Epoch 4 Iteration 75
# 0.029607061
# Epoch 4 Iteration 76
# 0.029640425
# Epoch 4 Iteration 77
# 0.029720087
# Epoch 4 Iteration 78
# 0.02988879
# Epoch 4 Iteration 79
# 0.03082559
# Epoch 4 Iteration 80
# 0.032612976
# Epoch 4 Iteration 81
# 0.035395335
# Epoch 4 Iteration 82
# 0.033298545
# Epoch 4 Iteration 83
# 0.02934772
# Epoch 4 Iteration 84
# 0.02835254
# Epoch 4 Iteration 85
# 0.030319797
# Epoch 4 Iteration 86
# 0.032722022
# Epoch 4 Iteration 87
# 0.0329802
# Epoch 4 Iteration 88
# 0.030036017
# Epoch 4 Iteration 89
# 0.028541615
# Epoch 4 Iteration 90
# 0.029471107
# Epoch 4 Iteration 91
# 0.03016048
# Epoch 4 Iteration 92
# 0.030687235
# Epoch 4 Iteration 93
# 0.028751891
# Epoch 4 Iteration 94
# 0.027523253
# Epoch 4 Iteration 95
# 0.028060827
# Epoch 4 Iteration 96
# 0.029643085
# Epoch 4 Iteration 97
# 0.030485652
# Epoch 4 Iteration 98
# 0.029005412
# Epoch 4 Iteration 99
# 0.027951213
# Epoch 4 Iteration 100
# 0.027041674
# Epoch 4 Iteration 101
# 0.027358785
# Epoch 4 Iteration 102
# 0.027421296
# Epoch 4 Iteration 103
# 0.027646363
# Epoch 4 Iteration 104
# 0.027635872
# Epoch 4 Iteration 105
# 0.026722267
# Epoch 4 Iteration 106
# 0.026109569
# Epoch 4 Iteration 107
# 0.026685843
# Epoch 4 Iteration 108
# 0.028966974
# Epoch 4 Iteration 109
# 0.035008207
# Epoch 4 Iteration 110
# 0.03787618
# Epoch 4 Iteration 111
# 0.038432125
# Epoch 4 Iteration 112
# 0.035136696
# Epoch 4 Iteration 113
# 0.039373897
# Epoch 4 Iteration 114
# 0.041250136
# Epoch 4 Iteration 115
# 0.039356027
# Epoch 4 Iteration 116
# 0.03792256
# Epoch 4 Iteration 117
# 0.035276596
# Epoch 4 Iteration 118
# 0.0326295
# Epoch 4 Iteration 119
# 0.03363532
# Epoch 4 Iteration 120
# 0.03314595
# Epoch 4 Iteration 121
# 0.033460103
# Epoch 4 Iteration 122
# 0.032781117
# Epoch 4 Iteration 123
# 0.032233346
# Epoch 4 Iteration 124
# 0.033556446
# Epoch 4 Iteration 125
# 0.0339567
# Epoch 4 Iteration 126
# 0.03550037
# Epoch 4 Iteration 127
# 0.0339782
# Epoch 4 Iteration 128
# 0.031139344
# Epoch 4 Iteration 129
# 0.029942764
# Epoch 4 Iteration 130
# 0.029546132
# Epoch 4 Iteration 131
# 0.029556248
# Epoch 4 Iteration 132
# 0.030275214
# Epoch 4 Iteration 133
# 0.029821105
# Epoch 4 Iteration 134
# 0.02923149
# Epoch 4 Iteration 135
# 0.028376695
# Epoch 4 Iteration 136
# 0.028390376
# Epoch 4 Iteration 137
# 0.028830212
# Epoch 4 Iteration 138
# 0.028649125
# Epoch 4 Iteration 139
# 0.028384957
# Epoch 4 Iteration 140
# 0.0276157
# Epoch 4 Iteration 141
# 0.02720536
# Epoch 4 Iteration 142
# 0.027501088
# Epoch 4 Iteration 143
# 0.027548544
# Epoch 4 Iteration 144
# 0.027626392
# Epoch 4 Iteration 145
# 0.027572641
# Epoch 4 Iteration 146
# 0.02725966
# Epoch 4 Iteration 147
# 0.026919916
# Epoch 4 Iteration 148
# 0.026429422
# Epoch 4 Iteration 149
# 0.026080409
# Epoch 4 Iteration 150
# 0.025977595
# Epoch 4 Iteration 151
# 0.025992185
# Epoch 4 Iteration 152
# 0.025823416
# Epoch 4 Iteration 153
# 0.0260407
# Epoch 4 Iteration 154
# 0.027645491
# Epoch 4 Iteration 155
# 0.034204274
# Epoch 4 Iteration 156
# 0.04143126
# Epoch 4 Iteration 157
# 0.03249938
# Epoch 4 Iteration 158
# 0.04083777
# Epoch 4 Iteration 159
# 0.037021127
# Epoch 4 Iteration 160
# 0.03197149
# Epoch 4 Iteration 161
# 0.032647237
# Epoch 4 Iteration 162
# 0.03060484
# Epoch 4 Iteration 163
# 0.032677427
# Epoch 4 Iteration 164
# 0.030398086
# Epoch 4 Iteration 165
# 0.03245288
# Epoch 4 Iteration 166
# 0.034485757
# Epoch 4 Iteration 167
# 0.0391538
# Epoch 4 Iteration 168
# 0.030835096
# Epoch 4 Iteration 169
# 0.03388018
# Epoch 4 Iteration 170
# 0.040232
# Epoch 4 Iteration 171
# 0.030691404
# Epoch 4 Iteration 172
# 0.0485211
# Epoch 4 Iteration 173
# 0.0326725
# Epoch 4 Iteration 174
# 0.057896513
# Epoch 4 Iteration 175
# 0.04787921
# Epoch 4 Iteration 176
# 0.04658152
# Epoch 4 Iteration 177
# 0.03942116
# Epoch 4 Iteration 178
# 0.056806907
# Epoch 4 Iteration 179
# 0.046664093
# Epoch 4 Iteration 180
# 0.054125857
# Epoch 4 Iteration 181
# 0.045956686
# Epoch 4 Iteration 182
# 0.04652375
# Epoch 4 Iteration 183
# 0.04644316
# Epoch 4 Iteration 184
# 0.04383865
# Epoch 4 Iteration 185
# 0.039038092
# Epoch 4 Iteration 186
# 0.05689165
# Epoch 4 Iteration 187
# 0.052365188
# Epoch 4 Iteration 188
# 0.03588229
# Epoch 4 Iteration 189
# 0.034609925
# Epoch 4 Iteration 190
# 0.046604525
# Epoch 4 Iteration 191
# 0.037118956
# Epoch 4 Iteration 192
# 0.050569605
# Epoch 4 Iteration 193
# 0.048419833
# Epoch 4 Iteration 194
# 0.039306212
# Epoch 4 Iteration 195
# 0.033428136
# Epoch 4 Iteration 196
# 0.04889062
# Epoch 4 Iteration 197
# 0.04121162
# Epoch 4 Iteration 198
# 0.04553242
# Epoch 4 Iteration 199
# 0.04234108
# Epoch 4 Iteration 200
# 0.042160384
# Epoch 4 Iteration 201
# 0.03905433
# Epoch 4 Iteration 202
# 0.04736901
# Epoch 4 Iteration 203
# 0.048313007
# Epoch 4 Iteration 204
# 0.034728527
# Epoch 4 Iteration 205
# 0.033702917
# Epoch 4 Iteration 206
# 0.04249602
# Epoch 4 Iteration 207
# 0.03548585
# Epoch 4 Iteration 208
# 0.050090082
# Epoch 4 Iteration 209
# 0.045447882
# Epoch 4 Iteration 210
# 0.04548128
# Epoch 4 Iteration 211
# 0.043790106
# Epoch 4 Iteration 212
# 0.043904774
# Epoch 4 Iteration 213
# 0.036518168
# Epoch 4 Iteration 214
# 0.053365666
# Epoch 4 Iteration 215
# 0.048067335
# Epoch 4 Iteration 216
# 0.03802409
# Epoch 4 Iteration 217
# 0.03398512
# Epoch 4 Iteration 218
# 0.041777626
# Epoch 4 Iteration 219
# 0.033517033
# Epoch 4 Iteration 220
# 0.04613438
# Epoch 4 Iteration 221
# 0.03768131
# Epoch 4 Iteration 222
# 0.054576915
# Epoch 4 Iteration 223
# 0.055435743
# Epoch 4 Iteration 224
# 0.039403774
# Epoch 4 Iteration 225
# 0.03571256
# Epoch 4 Iteration 226
# 0.05125425
# Epoch 4 Iteration 227
# 0.04001618
# Epoch 4 Iteration 228
# 0.055491243
# Epoch 4 Iteration 229
# 0.06207049
# Epoch 4 Iteration 230
# 0.04302993
# Epoch 4 Iteration 231
# 0.04094804
# Epoch 4 Iteration 232
# 0.042035934
# Epoch 4 Iteration 233
# 0.039321054
# Epoch 4 Iteration 234
# 0.03391904
# Epoch 4 Iteration 235
# 0.036052547
# Epoch 4 Iteration 236
# 0.03517903
# Epoch 4 Iteration 237
# 0.03374296
# Epoch 4 Iteration 238
# 0.03473682
# Epoch 4 Iteration 239
# 0.033345617
# Epoch 4 Iteration 240
# 0.031360175
# Epoch 4 Iteration 241
# 0.03256135
# Epoch 4 Iteration 242
# 0.0328039
# Epoch 4 Iteration 243
# 0.031462334
# Epoch 4 Iteration 244
# 0.030571256
# Epoch 4 Iteration 245
# 0.030697776
# Epoch 4 Iteration 246
# 0.032332294
# Epoch 4 Iteration 247
# 0.03317951
# Epoch 4 Iteration 248
# 0.031318195
# Epoch 4 Iteration 249
# 0.029763842
# Epoch 4 Iteration 250
# 0.031051958
# Epoch 4 Iteration 251
# 0.03002527
# Epoch 4 Iteration 252
# 0.030085359
# Epoch 4 Iteration 253
# 0.029046578
# Epoch 4 Iteration 254
# 0.02923853
# Epoch 4 Iteration 255
# 0.029385082
# Epoch 4 Iteration 256
# 0.02807329
# Epoch 4 Iteration 257
# 0.02862239
# Epoch 4 Iteration 258
# 0.028029917
# Epoch 4 Iteration 259
# 0.028042067
# Epoch 4 Iteration 260
# 0.027948903
# Epoch 4 Iteration 261
# 0.027274787
# Epoch 4 Iteration 262
# 0.027794812
# Epoch 4 Iteration 263
# 0.028193923
# Epoch 4 Iteration 264
# 0.027661422
# Epoch 4 Iteration 265
# 0.027811546
# Epoch 4 Iteration 266
# 0.02703721
# Epoch 4 Iteration 267
# 0.026144935
# Epoch 4 Iteration 268
# 0.026269179
# Epoch 4 Iteration 269
# 0.026272763
# Epoch 4 Iteration 270
# 0.02580237
# Epoch 4 Iteration 271
# 0.02582985
# Epoch 4 Iteration 272
# 0.02721845
# Epoch 4 Iteration 273
# 0.02708339
# Epoch 4 Iteration 274
# 0.026022669
# Epoch 4 Iteration 275
# 0.026055219
# Epoch 4 Iteration 276
# 0.026213165
# Epoch 4 Iteration 277
# 0.026542312
# Epoch 4 Iteration 278
# 0.027360365
# Epoch 4 Iteration 279
# 0.029761404
# Epoch 4 Iteration 280
# 0.029551711
# Epoch 4 Iteration 281
# 0.026170172
# Epoch 4 Iteration 282
# 0.024893155
# Epoch 4 Iteration 283
# 0.027265212
# Epoch 4 Iteration 284
# 0.027352557
# Epoch 4 Iteration 285
# 0.025227914
# Epoch 4 Iteration 286
# 0.025069153
# Epoch 4 Iteration 287
# 0.02547444
# Epoch 4 Iteration 288
# 0.025075555
# Epoch 4 Iteration 289
# 0.02514065
# Epoch 4 Iteration 290
# 0.027390923
# Epoch 4 Iteration 291
# 0.031087033
# Epoch 4 Iteration 292
# 0.027427236
# Epoch 4 Iteration 293
# 0.029660564
# Epoch 4 Iteration 294
# 0.027043208
# Epoch 4 Iteration 295
# 0.027749477
# Epoch 4 Iteration 296
# 0.027487358
# Epoch 4 Iteration 297
# 0.02698565
# Epoch 4 Iteration 298
# 0.02600383
# Epoch 4 Iteration 299
# 0.026143001
# Epoch 4 Iteration 300
# 0.026231766
# Epoch 5 Iteration 1
# 0.025702117
# Epoch 5 Iteration 2
# 0.025317976
# Epoch 5 Iteration 3
# 0.02528488
# Epoch 5 Iteration 4
# 0.024661005
# Epoch 5 Iteration 5
# 0.024516817
# Epoch 5 Iteration 6
# 0.024277356
# Epoch 5 Iteration 7
# 0.023987958
# Epoch 5 Iteration 8
# 0.023853961
# Epoch 5 Iteration 9
# 0.0241215
# Epoch 5 Iteration 10
# 0.02389522
# Epoch 5 Iteration 11
# 0.024081547
# Epoch 5 Iteration 12
# 0.023347922
# Epoch 5 Iteration 13
# 0.023344176
# Epoch 5 Iteration 14
# 0.02328784
# Epoch 5 Iteration 15
# 0.024188405
# Epoch 5 Iteration 16
# 0.027400278
# Epoch 5 Iteration 17
# 0.026126303
# Epoch 5 Iteration 18
# 0.025217567
# Epoch 5 Iteration 19
# 0.025257062
# Epoch 5 Iteration 20
# 0.02420804
# Epoch 5 Iteration 21
# 0.024854492
# Epoch 5 Iteration 22
# 0.025251105
# Epoch 5 Iteration 23
# 0.024984853
# Epoch 5 Iteration 24
# 0.024733145
# Epoch 5 Iteration 25
# 0.024289899
# Epoch 5 Iteration 26
# 0.024365019
# Epoch 5 Iteration 27
# 0.023041815
# Epoch 5 Iteration 28
# 0.024392202
# Epoch 5 Iteration 29
# 0.023670828
# Epoch 5 Iteration 30
# 0.023162993
# Epoch 5 Iteration 31
# 0.023306444
# Epoch 5 Iteration 32
# 0.023281217
# Epoch 5 Iteration 33
# 0.022914855
# Epoch 5 Iteration 34
# 0.02270871
# Epoch 5 Iteration 35
# 0.023116803
# Epoch 5 Iteration 36
# 0.024619117
# Epoch 5 Iteration 37
# 0.029108562
# Epoch 5 Iteration 38
# 0.02528522
# Epoch 5 Iteration 39
# 0.027805788
# Epoch 5 Iteration 40
# 0.026191453
# Epoch 5 Iteration 41
# 0.025136458
# Epoch 5 Iteration 42
# 0.025413087
# Epoch 5 Iteration 43
# 0.025397258
# Epoch 5 Iteration 44
# 0.02591663
# Epoch 5 Iteration 45
# 0.027689366
# Epoch 5 Iteration 46
# 0.02825407
# Epoch 5 Iteration 47
# 0.026796779
# Epoch 5 Iteration 48
# 0.024211168
# Epoch 5 Iteration 49
# 0.024490692
# Epoch 5 Iteration 50
# 0.025749153
# Epoch 5 Iteration 51
# 0.025571125
# Epoch 5 Iteration 52
# 0.023844324
# Epoch 5 Iteration 53
# 0.022868074
# Epoch 5 Iteration 54
# 0.023626309
# Epoch 5 Iteration 55
# 0.023950033
# Epoch 5 Iteration 56
# 0.023135422
# Epoch 5 Iteration 57
# 0.022444068
# Epoch 5 Iteration 58
# 0.022387093
# Epoch 5 Iteration 59
# 0.022692062
# Epoch 5 Iteration 60
# 0.022604128
# Epoch 5 Iteration 61
# 0.02207747
# Epoch 5 Iteration 62
# 0.022405136
# Epoch 5 Iteration 63
# 0.02227978
# Epoch 5 Iteration 64
# 0.022565162
# Epoch 5 Iteration 65
# 0.02322538
# Epoch 5 Iteration 66
# 0.023413653
# Epoch 5 Iteration 67
# 0.022541694
# Epoch 5 Iteration 68
# 0.022130305
# Epoch 5 Iteration 69
# 0.022077749
# Epoch 5 Iteration 70
# 0.02267082
# Epoch 5 Iteration 71
# 0.024116118
# Epoch 5 Iteration 72
# 0.023491552
# Epoch 5 Iteration 73
# 0.022637604
# Epoch 5 Iteration 74
# 0.022433896
# Epoch 5 Iteration 75
# 0.02246728
# Epoch 5 Iteration 76
# 0.022453416
# Epoch 5 Iteration 77
# 0.022933614
# Epoch 5 Iteration 78
# 0.024425618
# Epoch 5 Iteration 79
# 0.024053458
# Epoch 5 Iteration 80
# 0.02330436
# Epoch 5 Iteration 81
# 0.022995837
# Epoch 5 Iteration 82
# 0.022670632
# Epoch 5 Iteration 83
# 0.023942001
# Epoch 5 Iteration 84
# 0.023722433
# Epoch 5 Iteration 85
# 0.023425326
# Epoch 5 Iteration 86
# 0.023498068
# Epoch 5 Iteration 87
# 0.02247396
# Epoch 5 Iteration 88
# 0.022293795
# Epoch 5 Iteration 89
# 0.02322356
# Epoch 5 Iteration 90
# 0.02349273
# Epoch 5 Iteration 91
# 0.023424778
# Epoch 5 Iteration 92
# 0.022626627
# Epoch 5 Iteration 93
# 0.02300739
# Epoch 5 Iteration 94
# 0.022161132
# Epoch 5 Iteration 95
# 0.022128772
# Epoch 5 Iteration 96
# 0.022735218
# Epoch 5 Iteration 97
# 0.022997653
# Epoch 5 Iteration 98
# 0.023544779
# Epoch 5 Iteration 99
# 0.022217607
# Epoch 5 Iteration 100
# 0.023739938
# Epoch 5 Iteration 101
# 0.023343591
# Epoch 5 Iteration 102
# 0.02185625
# Epoch 5 Iteration 103
# 0.02404581
# Epoch 5 Iteration 104
# 0.022636237
# Epoch 5 Iteration 105
# 0.023144405
# Epoch 5 Iteration 106
# 0.022022549
# Epoch 5 Iteration 107
# 0.023005582
# Epoch 5 Iteration 108
# 0.021662738
# Epoch 5 Iteration 109
# 0.022038382
# Epoch 5 Iteration 110
# 0.021510443
# Epoch 5 Iteration 111
# 0.022069713
# Epoch 5 Iteration 112
# 0.022339538
# Epoch 5 Iteration 113
# 0.022016168
# Epoch 5 Iteration 114
# 0.022318194
# Epoch 5 Iteration 115
# 0.022306265
# Epoch 5 Iteration 116
# 0.022054441
# Epoch 5 Iteration 117
# 0.02283242
# Epoch 5 Iteration 118
# 0.023465186
# Epoch 5 Iteration 119
# 0.025868304
# Epoch 5 Iteration 120
# 0.026297435
# Epoch 5 Iteration 121
# 0.025358157
# Epoch 5 Iteration 122
# 0.02427357
# Epoch 5 Iteration 123
# 0.023177022
# Epoch 5 Iteration 124
# 0.02391626
# Epoch 5 Iteration 125
# 0.02445304
# Epoch 5 Iteration 126
# 0.023543686
# Epoch 5 Iteration 127
# 0.023594884
# Epoch 5 Iteration 128
# 0.022608472
# Epoch 5 Iteration 129
# 0.022038098
# Epoch 5 Iteration 130
# 0.022494778
# Epoch 5 Iteration 131
# 0.02251564
# Epoch 5 Iteration 132
# 0.022744378
# Epoch 5 Iteration 133
# 0.022630848
# Epoch 5 Iteration 134
# 0.021905422
# Epoch 5 Iteration 135
# 0.020894084
# Epoch 5 Iteration 136
# 0.020996705
# Epoch 5 Iteration 137
# 0.020639934
# Epoch 5 Iteration 138
# 0.020911979
# Epoch 5 Iteration 139
# 0.02120867
# Epoch 5 Iteration 140
# 0.0214332
# Epoch 5 Iteration 141
# 0.02166518
# Epoch 5 Iteration 142
# 0.02282402
# Epoch 5 Iteration 143
# 0.022696905
# Epoch 5 Iteration 144
# 0.020982075
# Epoch 5 Iteration 145
# 0.02142662
# Epoch 5 Iteration 146
# 0.021691961
# Epoch 5 Iteration 147
# 0.020557832
# Epoch 5 Iteration 148
# 0.020474162
# Epoch 5 Iteration 149
# 0.021245588
# Epoch 5 Iteration 150
# 0.020777887
# Epoch 5 Iteration 151
# 0.020530216
# Epoch 5 Iteration 152
# 0.020800954
# Epoch 5 Iteration 153
# 0.020059709
# Epoch 5 Iteration 154
# 0.02060348
# Epoch 5 Iteration 155
# 0.020869967
# Epoch 5 Iteration 156
# 0.020884756
# Epoch 5 Iteration 157
# 0.02043361
# Epoch 5 Iteration 158
# 0.02024594
# Epoch 5 Iteration 159
# 0.021171696
# Epoch 5 Iteration 160
# 0.02254955
# Epoch 5 Iteration 161
# 0.022890551
# Epoch 5 Iteration 162
# 0.021953788
# Epoch 5 Iteration 163
# 0.022669706
# Epoch 5 Iteration 164
# 0.023250267
# Epoch 5 Iteration 165
# 0.021215703
# Epoch 5 Iteration 166
# 0.021280836
# Epoch 5 Iteration 167
# 0.022007078
# Epoch 5 Iteration 168
# 0.021099847
# Epoch 5 Iteration 169
# 0.020124855
# Epoch 5 Iteration 170
# 0.020434478
# Epoch 5 Iteration 171
# 0.020043394
# Epoch 5 Iteration 172
# 0.019801468
# Epoch 5 Iteration 173
# 0.020019352
# Epoch 5 Iteration 174
# 0.020070165
# Epoch 5 Iteration 175
# 0.020284118
# Epoch 5 Iteration 176
# 0.019399844
# Epoch 5 Iteration 177
# 0.020052735
# Epoch 5 Iteration 178
# 0.020834303
# Epoch 5 Iteration 179
# 0.020404886
# Epoch 5 Iteration 180
# 0.02029282
# Epoch 5 Iteration 181
# 0.020602781
# Epoch 5 Iteration 182
# 0.020976286
# Epoch 5 Iteration 183
# 0.021552596
# Epoch 5 Iteration 184
# 0.022027694
# Epoch 5 Iteration 185
# 0.022879308
# Epoch 5 Iteration 186
# 0.02108033
# Epoch 5 Iteration 187
# 0.02341459
# Epoch 5 Iteration 188
# 0.02470418
# Epoch 5 Iteration 189
# 0.020422619
# Epoch 5 Iteration 190
# 0.023537124
# Epoch 5 Iteration 191
# 0.021803845
# Epoch 5 Iteration 192
# 0.021406481
# Epoch 5 Iteration 193
# 0.021308508
# Epoch 5 Iteration 194
# 0.020203212
# Epoch 5 Iteration 195
# 0.021192623
# Epoch 5 Iteration 196
# 0.02022766
# Epoch 5 Iteration 197
# 0.020761285
# Epoch 5 Iteration 198
# 0.019545235
# Epoch 5 Iteration 199
# 0.020242631
# Epoch 5 Iteration 200
# 0.019427728
# Epoch 5 Iteration 201
# 0.019741468
# Epoch 5 Iteration 202
# 0.019184014
# Epoch 5 Iteration 203
# 0.019151395
# Epoch 5 Iteration 204
# 0.019476954
# Epoch 5 Iteration 205
# 0.01947394
# Epoch 5 Iteration 206
# 0.021297742
# Epoch 5 Iteration 207
# 0.020837858
# Epoch 5 Iteration 208
# 0.0203233
# Epoch 5 Iteration 209
# 0.020260204
# Epoch 5 Iteration 210
# 0.021232776
# Epoch 5 Iteration 211
# 0.023002367
# Epoch 5 Iteration 212
# 0.025762476
# Epoch 5 Iteration 213
# 0.029493293
# Epoch 5 Iteration 214
# 0.023918062
# Epoch 5 Iteration 215
# 0.021782672
# Epoch 5 Iteration 216
# 0.022743065
# Epoch 5 Iteration 217
# 0.02577613
# Epoch 5 Iteration 218
# 0.029225651
# Epoch 5 Iteration 219
# 0.022088708
# Epoch 5 Iteration 220
# 0.024549738
# Epoch 5 Iteration 221
# 0.029848978
# Epoch 5 Iteration 222
# 0.022411022
# Epoch 5 Iteration 223
# 0.022572301
# Epoch 5 Iteration 224
# 0.026993575
# Epoch 5 Iteration 225
# 0.024532482
# Epoch 5 Iteration 226
# 0.021559108
# Epoch 5 Iteration 227
# 0.02083245
# Epoch 5 Iteration 228
# 0.021900691
# Epoch 5 Iteration 229
# 0.024473995
# Epoch 5 Iteration 230
# 0.026014192
# Epoch 5 Iteration 231
# 0.024492092
# Epoch 5 Iteration 232
# 0.024162443
# Epoch 5 Iteration 233
# 0.023977326
# Epoch 5 Iteration 234
# 0.024208145
# Epoch 5 Iteration 235
# 0.023715151
# Epoch 5 Iteration 236
# 0.021862112
# Epoch 5 Iteration 237
# 0.02127248
# Epoch 5 Iteration 238
# 0.022427978
# Epoch 5 Iteration 239
# 0.022140115
# Epoch 5 Iteration 240
# 0.021020425
# Epoch 5 Iteration 241
# 0.019799143
# Epoch 5 Iteration 242
# 0.020474609
# Epoch 5 Iteration 243
# 0.020406103
# Epoch 5 Iteration 244
# 0.019791516
# Epoch 5 Iteration 245
# 0.01998177
# Epoch 5 Iteration 246
# 0.019255884
# Epoch 5 Iteration 247
# 0.019477088
# Epoch 5 Iteration 248
# 0.019547587
# Epoch 5 Iteration 249
# 0.019053876
# Epoch 5 Iteration 250
# 0.018983964
# Epoch 5 Iteration 251
# 0.019001588
# Epoch 5 Iteration 252
# 0.018510178
# Epoch 5 Iteration 253
# ...
# 0.00034096857
# Epoch 68 Iteration 253
# 0.0003436699
# Epoch 68 Iteration 254
# 0.00034175365
# Epoch 68 Iteration 255
# 0.00033389917
# Epoch 68 Iteration 256
# 0.0003289101
# Epoch 68 Iteration 257
# 0.00033251024
# Epoch 68 Iteration 258
# 0.00033453852
# Epoch 68 Iteration 259
# 0.00033164362
# Epoch 68 Iteration 260
# 0.0003291541
# Epoch 68 Iteration 261
# 0.00032886586
# Epoch 68 Iteration 262
# 0.0003287348
# Epoch 68 Iteration 263
# 0.00032743538
# Epoch 68 Iteration 264
# 0.00032587704
# Epoch 68 Iteration 265
# 0.0003241579
# Epoch 68 Iteration 266
# 0.0003213415
# Epoch 68 Iteration 267
# 0.00031973902
# Epoch 68 Iteration 268
# 0.0003204127
# Epoch 68 Iteration 269
# 0.00032064135
# Epoch 68 Iteration 270
# 0.00031843313
# Epoch 68 Iteration 271
# 0.0003159491
# Epoch 68 Iteration 272
# 0.00031613922
# Epoch 68 Iteration 273
# 0.00031765396
# Epoch 68 Iteration 274
# 0.0003176859
# Epoch 68 Iteration 275
# 0.00031630322
# Epoch 68 Iteration 276
# 0.00031552502
# Epoch 68 Iteration 277
# 0.00031583398
# Epoch 68 Iteration 278
# 0.0003162655
# Epoch 68 Iteration 279
# 0.00031597097
# Epoch 68 Iteration 280
# 0.0003154876
# Epoch 68 Iteration 281
# 0.0003153903
# Epoch 68 Iteration 282
# 0.00031562967
# Epoch 68 Iteration 283
# 0.00031572024
# Epoch 68 Iteration 284
# 0.00031564754
# Epoch 68 Iteration 285
# 0.00031557964
# Epoch 68 Iteration 286
# 0.00031570898
# Epoch 68 Iteration 287
# 0.0003161086
# Epoch 68 Iteration 288
# 0.00031667386
# Epoch 68 Iteration 289
# 0.0003172886
# Epoch 68 Iteration 290
# 0.00031814477
# Epoch 68 Iteration 291
# 0.00031945942
# Epoch 68 Iteration 292
# 0.00032131834
# Epoch 68 Iteration 293
# 0.00032377092
# Epoch 68 Iteration 294
# 0.00032745025
# Epoch 68 Iteration 295
# 0.00033254095
# Epoch 68 Iteration 296
# 0.00033996743
# Epoch 68 Iteration 297
# 0.00035000592
# Epoch 68 Iteration 298
# 0.00036503247
# Epoch 68 Iteration 299
# 0.00038577637
# Epoch 68 Iteration 300
# 0.0004175491
# Epoch 69 Iteration 1
# 0.0004605592
# Epoch 69 Iteration 2
# 0.00052713277
# Epoch 69 Iteration 3
# 0.00061383075
# Epoch 69 Iteration 4
# 0.00074923993
# Epoch 69 Iteration 5
# 0.0009097776
# Epoch 69 Iteration 6
# 0.0011550264
# Epoch 69 Iteration 7
# 0.0013911473
# Epoch 69 Iteration 8
# 0.0017233407
# Epoch 69 Iteration 9
# 0.0019151012
# Epoch 69 Iteration 10
# 0.0021342654
# Epoch 69 Iteration 11
# 0.002083322
# Epoch 69 Iteration 12
# 0.0020024811
# Epoch 69 Iteration 13
# 0.0017707378
# Epoch 69 Iteration 14
# 0.0015301307
# Epoch 69 Iteration 15
# 0.0012910527
# Epoch 69 Iteration 16
# 0.000990971
# Epoch 69 Iteration 17
# 0.0007392911
# Epoch 69 Iteration 18
# 0.00056904403
# Epoch 69 Iteration 19
# 0.0005517842
# Epoch 69 Iteration 20
# 0.0006759488
# Epoch 69 Iteration 21
# 0.0008130588
# Epoch 69 Iteration 22
# 0.00088714645
# Epoch 69 Iteration 23
# 0.0008696901
# Epoch 69 Iteration 24
# 0.0007888958
# Epoch 69 Iteration 25
# 0.0007069456
# Epoch 69 Iteration 26
# 0.0006343998
# Epoch 69 Iteration 27
# 0.0005785426
# Epoch 69 Iteration 28
# 0.00050508464
# Epoch 69 Iteration 29
# 0.00044372663
# Epoch 69 Iteration 30
# 0.00040743416
# Epoch 69 Iteration 31
# 0.0004144214
# Epoch 69 Iteration 32
# 0.00044405521
# Epoch 69 Iteration 33
# 0.0004627207
# Epoch 69 Iteration 34
# 0.00046256397
# Epoch 69 Iteration 35
# 0.00044519105
# Epoch 69 Iteration 36
# 0.00043546743
# Epoch 69 Iteration 37
# 0.00043025066
# Epoch 69 Iteration 38
# 0.0004183856
# Epoch 69 Iteration 39
# 0.00040050724
# Epoch 69 Iteration 40
# 0.00038484274
# Epoch 69 Iteration 41
# 0.00037561887
# Epoch 69 Iteration 42
# 0.0003667847
# Epoch 69 Iteration 43
# 0.0003543448
# Epoch 69 Iteration 44
# 0.00034075696
# Epoch 69 Iteration 45
# 0.00033224927
# Epoch 69 Iteration 46
# 0.00033551862
# Epoch 69 Iteration 47
# 0.00034586934
# Epoch 69 Iteration 48
# 0.00035273476
# Epoch 69 Iteration 49
# 0.0003498136
# Epoch 69 Iteration 50
# 0.00033890567
# Epoch 69 Iteration 51
# 0.00033178733
# Epoch 69 Iteration 52
# 0.00033408677
# Epoch 69 Iteration 53
# 0.0003409394
# Epoch 69 Iteration 54
# 0.00034450117
# Epoch 69 Iteration 55
# 0.0003406639
# Epoch 69 Iteration 56
# 0.00033331168
# Epoch 69 Iteration 57
# 0.0003285654
# Epoch 69 Iteration 58
# 0.00032872334
# Epoch 69 Iteration 59
# 0.00033194458
# Epoch 69 Iteration 60
# 0.00033309672
# Epoch 69 Iteration 61
# 0.00033111227
# Epoch 69 Iteration 62
# 0.000327801
# Epoch 69 Iteration 63
# 0.00032646858
# Epoch 69 Iteration 64
# 0.0003277443
# Epoch 69 Iteration 65
# 0.0003302579
# Epoch 69 Iteration 66
# 0.00033177817
# Epoch 69 Iteration 67
# 0.00033215352
# Epoch 69 Iteration 68
# 0.00033226507
# Epoch 69 Iteration 69
# 0.00033381052
# Epoch 69 Iteration 70
# 0.00033720856
# Epoch 69 Iteration 71
# 0.00034253954
# Epoch 69 Iteration 72
# 0.00034844055
# Epoch 69 Iteration 73
# 0.000356111
# Epoch 69 Iteration 74
# 0.00036501652
# Epoch 69 Iteration 75
# 0.00037775075
# Epoch 69 Iteration 76
# 0.0003934328
# Epoch 69 Iteration 77
# 0.00041538218
# Epoch 69 Iteration 78
# 0.00044164836
# Epoch 69 Iteration 79
# 0.00047769386
# Epoch 69 Iteration 80
# 0.0005195695
# Epoch 69 Iteration 81
# 0.0005777287
# Epoch 69 Iteration 82
# 0.0006414113
# Epoch 69 Iteration 83
# 0.0007303078
# Epoch 69 Iteration 84
# 0.00081897737
# Epoch 69 Iteration 85
# 0.00094643363
# Epoch 69 Iteration 86
# 0.0010642883
# Epoch 69 Iteration 87
# 0.0012494556
# Epoch 69 Iteration 88
# 0.0014220113
# Epoch 69 Iteration 89
# 0.001700919
# Epoch 69 Iteration 90
# 0.0019592207
# Epoch 69 Iteration 91
# 0.0023101126
# Epoch 69 Iteration 92
# 0.002563804
# Epoch 69 Iteration 93
# 0.0026712427
# Epoch 69 Iteration 94
# 0.002511895
# Epoch 69 Iteration 95
# 0.0020022583
# Epoch 69 Iteration 96
# 0.0014951853
# Epoch 69 Iteration 97
# 0.0012813276
# Epoch 69 Iteration 98
# 0.0014021837
# Epoch 69 Iteration 99
# 0.001667039
# Epoch 69 Iteration 100
# 0.0013283568
# Epoch 69 Iteration 101
# 0.0009901507
# Epoch 69 Iteration 102
# 0.0008802806
# Epoch 69 Iteration 103
# 0.001029262
# Epoch 69 Iteration 104
# 0.000961739
# Epoch 69 Iteration 105
# 0.0006978211
# Epoch 69 Iteration 106
# 0.0007290294
# Epoch 69 Iteration 107
# 0.0007918947
# Epoch 69 Iteration 108
# 0.00069036364
# Epoch 69 Iteration 109
# 0.0006083468
# Epoch 69 Iteration 110
# 0.00058512343
# Epoch 69 Iteration 111
# 0.0006186542
# Epoch 69 Iteration 112
# 0.0006043888
# Epoch 69 Iteration 113
# 0.00052415254
# Epoch 69 Iteration 114
# 0.0005367714
# Epoch 69 Iteration 115
# 0.0005811728
# Epoch 69 Iteration 116
# 0.0005556602
# Epoch 69 Iteration 117
# 0.0005362462
# Epoch 69 Iteration 118
# 0.00060121965
# Epoch 69 Iteration 119
# 0.0006525009
# Epoch 69 Iteration 120
# 0.0006679206
# Epoch 69 Iteration 121
# 0.00076270505
# Epoch 69 Iteration 122
# 0.0008843981
# Epoch 69 Iteration 123
# 0.0010399896
# Epoch 69 Iteration 124
# 0.00120893
# Epoch 69 Iteration 125
# 0.001419128
# Epoch 69 Iteration 126
# 0.0016254538
# Epoch 69 Iteration 127
# 0.0018638234
# Epoch 69 Iteration 128
# 0.0018933658
# Epoch 69 Iteration 129
# 0.0019241833
# Epoch 69 Iteration 130
# 0.0017507875
# Epoch 69 Iteration 131
# 0.0014964038
# Epoch 69 Iteration 132
# 0.0011424377
# Epoch 69 Iteration 133
# 0.0007783222
# Epoch 69 Iteration 134
# 0.0005429451
# Epoch 69 Iteration 135
# 0.00047318774
# Epoch 69 Iteration 136
# 0.00045540388
# Epoch 69 Iteration 137
# 0.0005367405
# Epoch 69 Iteration 138
# 0.0006896356
# Epoch 69 Iteration 139
# 0.0007829298
# Epoch 69 Iteration 140
# 0.00081069954
# Epoch 69 Iteration 141
# 0.00074855273
# Epoch 69 Iteration 142
# 0.0006633875
# Epoch 69 Iteration 143
# 0.0005475355
# Epoch 69 Iteration 144
# 0.00044141873
# Epoch 69 Iteration 145
# 0.00040761443
# Epoch 69 Iteration 146
# 0.0003928389
# Epoch 69 Iteration 147
# 0.00038287378
# Epoch 69 Iteration 148
# 0.00041690096
# Epoch 69 Iteration 149
# 0.00045264876
# Epoch 69 Iteration 150
# 0.00047840716
# Epoch 69 Iteration 151
# 0.0004786468
# Epoch 69 Iteration 152
# 0.00045478318
# Epoch 69 Iteration 153
# 0.00043097365
# Epoch 69 Iteration 154
# 0.0003958075
# Epoch 69 Iteration 155
# 0.00035389877
# Epoch 69 Iteration 156
# 0.00033684683
# Epoch 69 Iteration 157
# 0.0003406617
# Epoch 69 Iteration 158
# 0.00033966574
# Epoch 69 Iteration 159
# 0.00035082988
# Epoch 69 Iteration 160
# 0.00035994113
# Epoch 69 Iteration 161
# 0.00035959823
# Epoch 69 Iteration 162
# 0.00036309136
# Epoch 69 Iteration 163
# 0.0003601021
# Epoch 69 Iteration 164
# 0.00035199535
# Epoch 69 Iteration 165
# 0.00034598535
# Epoch 69 Iteration 166
# 0.00033700033
# Epoch 69 Iteration 167
# 0.00032777037
# Epoch 69 Iteration 168
# 0.0003222483
# Epoch 69 Iteration 169
# 0.0003184292
# Epoch 69 Iteration 170
# 0.00031758027
# Epoch 69 Iteration 171
# 0.00032048873
# Epoch 69 Iteration 172
# 0.00032182207
# Epoch 69 Iteration 173
# 0.0003231367
# Epoch 69 Iteration 174
# 0.0003260314
# Epoch 69 Iteration 175
# 0.0003261991
# Epoch 69 Iteration 176
# 0.00032589617
# Epoch 69 Iteration 177
# 0.00032656995
# Epoch 69 Iteration 178
# 0.00032633607
# Epoch 69 Iteration 179
# 0.00032452156
# Epoch 69 Iteration 180
# 0.0003222881
# Epoch 69 Iteration 181
# 0.00032042616
# Epoch 69 Iteration 182
# 0.00031932766
# Epoch 69 Iteration 183
# 0.00031825076
# Epoch 69 Iteration 184
# 0.00031735416
# Epoch 69 Iteration 185
# 0.00031752285
# Epoch 69 Iteration 186
# 0.00031837678
# Epoch 69 Iteration 187
# 0.00031978206
# Epoch 69 Iteration 188
# 0.00032181095
# Epoch 69 Iteration 189
# 0.00032524826
# Epoch 69 Iteration 190
# 0.0003304739
# Epoch 69 Iteration 191
# 0.00033795743
# Epoch 69 Iteration 192
# 0.00034805018
# Epoch 69 Iteration 193
# 0.00036273425
# Epoch 69 Iteration 194
# 0.00038274203
# Epoch 69 Iteration 195
# 0.0004105162
# Epoch 69 Iteration 196
# 0.0004472892
# Epoch 69 Iteration 197
# 0.0004969222
# Epoch 69 Iteration 198
# 0.0005581329
# Epoch 69 Iteration 199
# 0.0006327649
# Epoch 69 Iteration 200
# 0.00070998527
# Epoch 69 Iteration 201
# 0.0007805845
# Epoch 69 Iteration 202
# 0.0008220606
# Epoch 69 Iteration 203
# 0.00081731303
# Epoch 69 Iteration 204
# 0.0007696711
# Epoch 69 Iteration 205
# 0.00069393375
# Epoch 69 Iteration 206
# 0.00064721634
# Epoch 69 Iteration 207
# 0.0006589872
# Epoch 69 Iteration 208
# 0.0007706451
# Epoch 69 Iteration 209
# 0.0009414674
# Epoch 69 Iteration 210
# 0.0011717759
# Epoch 69 Iteration 211
# 0.001375859
# Epoch 69 Iteration 212
# 0.0015307595
# Epoch 69 Iteration 213
# 0.0016165447
# Epoch 69 Iteration 214
# 0.0016930683
# Epoch 69 Iteration 215
# 0.0017910441
# Epoch 69 Iteration 216
# 0.0019728949
# Epoch 69 Iteration 217
# 0.0020421057
# Epoch 69 Iteration 218
# 0.0019990539
# Epoch 69 Iteration 219
# 0.0017427976
# Epoch 69 Iteration 220
# 0.0015102653
# Epoch 69 Iteration 221
# 0.0016785928
# Epoch 69 Iteration 222
# 0.009399401
# Epoch 69 Iteration 223
# 0.019691736
# Epoch 69 Iteration 224
# 0.028847719
# Epoch 69 Iteration 225
# 0.05567338
# Epoch 69 Iteration 226
# 0.033653554
# Epoch 69 Iteration 227
# 0.0515596
# Epoch 69 Iteration 228
# 0.09103156
# Epoch 69 Iteration 229
# 0.04347075
# Epoch 69 Iteration 230
# 0.028450038
# Epoch 69 Iteration 231
# 0.037896812
# Epoch 69 Iteration 232
# 0.1336865
# Epoch 69 Iteration 233
# 0.060453203
# Epoch 69 Iteration 234
# 0.16130458
# Epoch 69 Iteration 235
# 0.13935801
# Epoch 69 Iteration 236
# 0.04727607
# Epoch 69 Iteration 237
# 0.032963477
# Epoch 69 Iteration 238
# 0.095068924
# Epoch 69 Iteration 239
# 0.057771444
# Epoch 69 Iteration 240
# 0.10117712
# Epoch 69 Iteration 241
# 0.08442486
# Epoch 69 Iteration 242
# 0.03872186
# Epoch 69 Iteration 243
# 0.026082592
# Epoch 69 Iteration 244
# 0.040964875
# Epoch 69 Iteration 245
# 0.0463369
# Epoch 69 Iteration 246
# 0.026286557
# Epoch 69 Iteration 247
# 0.029125689
# Epoch 69 Iteration 248
# 0.06773878
# Epoch 69 Iteration 249
# 0.047042288
# Epoch 69 Iteration 250
# 0.075625576
# Epoch 69 Iteration 251
# 0.07284835
# Epoch 69 Iteration 252
# 0.02834924
# Epoch 69 Iteration 253
# 0.029664986
# Epoch 69 Iteration 254
# 0.052967366
# Epoch 69 Iteration 255
# 0.0358844
# Epoch 69 Iteration 256
# 0.05611934
# Epoch 69 Iteration 257
# 0.06429525
# Epoch 69 Iteration 258
# 0.021846095
# Epoch 69 Iteration 259
# 0.049274445
# Epoch 69 Iteration 260
# 0.028492501
# Epoch 69 Iteration 261
# 0.075544395
# Epoch 69 Iteration 262
# 0.10170974
# Epoch 69 Iteration 263
# 0.03648677
# Epoch 69 Iteration 264
# 0.10455919
# Epoch 69 Iteration 265
# 0.17476511
# Epoch 69 Iteration 266
# 0.08640333
# Epoch 69 Iteration 267
# 0.04626853
# Epoch 69 Iteration 268
# 0.06175114
# Epoch 69 Iteration 269
# 0.032085765
# Epoch 69 Iteration 270
# 0.04873402
# Epoch 69 Iteration 271
# 0.02658866
# Epoch 69 Iteration 272
# 0.05844848
# Epoch 69 Iteration 273
# 0.05302758
# Epoch 69 Iteration 274
# 0.042315613
# Epoch 69 Iteration 275
# 0.033845846
# Epoch 69 Iteration 276
# 0.036828835
# Epoch 69 Iteration 277
# 0.030888911
# Epoch 69 Iteration 278
# 0.04255288
# Epoch 69 Iteration 279
# 0.044236496
# Epoch 69 Iteration 280
# 0.029838625
# Epoch 69 Iteration 281
# 0.027162882
# Epoch 69 Iteration 282
# 0.036556765
# Epoch 69 Iteration 283
# 0.026541198
# Epoch 69 Iteration 284
# 0.041562177
# Epoch 69 Iteration 285
# 0.044660576
# Epoch 69 Iteration 286
# 0.026065074
# Epoch 69 Iteration 287
# 0.026121553
# Epoch 69 Iteration 288
# 0.02985077
# Epoch 69 Iteration 289
# 0.01969618
# Epoch 69 Iteration 290
# 0.029881978
# Epoch 69 Iteration 291
# 0.022172352
# Epoch 69 Iteration 292
# 0.031827666
# Epoch 69 Iteration 293
# 0.023715846
# Epoch 69 Iteration 294
# 0.040403906
# Epoch 69 Iteration 295
# 0.04180726
# Epoch 69 Iteration 296
# 0.018595962
# Epoch 69 Iteration 297
# 0.03207381
# Epoch 69 Iteration 298
# 0.01831076
# Epoch 69 Iteration 299
# 0.03383217
# Epoch 69 Iteration 300
# 0.024779059
# Epoch 70 Iteration 1
# 0.03590062
# Epoch 70 Iteration 2
# 0.04215608
# Epoch 70 Iteration 3
# 0.018245129
# Epoch 70 Iteration 4
# 0.034571417
# Epoch 70 Iteration 5
# 0.024404224
# Epoch 70 Iteration 6
# 0.03815482
# Epoch 70 Iteration 7
# 0.050046023
# Epoch 70 Iteration 8
# 0.020781433
# Epoch 70 Iteration 9
# 0.047131803
# Epoch 70 Iteration 10
# 0.058074597
# Epoch 70 Iteration 11
# 0.022797639
# Epoch 70 Iteration 12
# 0.0464837
# Epoch 70 Iteration 13
# 0.063051015
# Epoch 70 Iteration 14
# 0.03185467
# Epoch 70 Iteration 15
# 0.051464915
# Epoch 70 Iteration 16
# 0.07698807
# Epoch 70 Iteration 17
# 0.047356796
# Epoch 70 Iteration 18
# 0.057559807
# Epoch 70 Iteration 19
# 0.093739554
# Epoch 70 Iteration 20
# 0.07561038
# Epoch 70 Iteration 21
# 0.05800997
# Epoch 70 Iteration 22
# 0.070930436
# Epoch 70 Iteration 23
# 0.03923029
# Epoch 70 Iteration 24
# 0.046384282
# Epoch 70 Iteration 25
# 0.06118676
# Epoch 70 Iteration 26
# 0.027168918
# Epoch 70 Iteration 27
# 0.06196329
# Epoch 70 Iteration 28
# 0.08868938
# Epoch 70 Iteration 29
# 0.03961664
# Epoch 70 Iteration 30
# 0.055054158
# Epoch 70 Iteration 31
# 0.08162649
# Epoch 70 Iteration 32
# 0.039824907
# Epoch 70 Iteration 33
# 0.039240688
# Epoch 70 Iteration 34
# 0.05789068
# Epoch 70 Iteration 35
# 0.028047575
# Epoch 70 Iteration 36
# 0.055708162
# Epoch 70 Iteration 37
# 0.07987585
# Epoch 70 Iteration 38
# 0.039186057
# Epoch 70 Iteration 39
# 0.04123541
# Epoch 70 Iteration 40
# 0.057192925
# Epoch 70 Iteration 41
# 0.026739534
# Epoch 70 Iteration 42
# 0.051346187
# Epoch 70 Iteration 43
# 0.07814937
# Epoch 70 Iteration 44
# 0.03973245
# Epoch 70 Iteration 45
# 0.031258717
# Epoch 70 Iteration 46
# 0.042498242
# Epoch 70 Iteration 47
# 0.02119339
# Epoch 70 Iteration 48
# 0.03641225
# Epoch 70 Iteration 49
# 0.036966044
# Epoch 70 Iteration 50
# 0.018746655
# Epoch 70 Iteration 51
# 0.034241244
# Epoch 70 Iteration 52
# 0.024860688
# Epoch 70 Iteration 53
# 0.025287116
# Epoch 70 Iteration 54
# 0.030393463
# Epoch 70 Iteration 55
# 0.016855408
# Epoch 70 Iteration 56
# 0.027056154
# Epoch 70 Iteration 57
# 0.019188765
# Epoch 70 Iteration 58
# 0.024833996
# Epoch 70 Iteration 59
# 0.023421584
# Epoch 70 Iteration 60
# 0.017153021
# Epoch 70 Iteration 61
# 0.0217531
# Epoch 70 Iteration 62
# 0.015320141
# Epoch 70 Iteration 63
# 0.020021718
# Epoch 70 Iteration 64
# 0.014657918
# Epoch 70 Iteration 65
# 0.018595291
# Epoch 70 Iteration 66
# 0.014290005
# Epoch 70 Iteration 67
# 0.017596623
# Epoch 70 Iteration 68
# 0.013743362
# Epoch 70 Iteration 69
# 0.016492648
# Epoch 70 Iteration 70
# 0.013777128
# Epoch 70 Iteration 71
# 0.015657615
# Epoch 70 Iteration 72
# 0.013263793
# Epoch 70 Iteration 73
# 0.015144795
# Epoch 70 Iteration 74
# 0.0130261155
# Epoch 70 Iteration 75
# 0.014579604
# Epoch 70 Iteration 76
# 0.012873734
# Epoch 70 Iteration 77
# 0.0140043255
# Epoch 70 Iteration 78
# 0.012684004
# Epoch 70 Iteration 79
# 0.013624561
# Epoch 70 Iteration 80
# 0.0125166755
# Epoch 70 Iteration 81
# 0.013350551
# Epoch 70 Iteration 82
# 0.01235161
# Epoch 70 Iteration 83
# 0.012987786
# Epoch 70 Iteration 84
# 0.012254093
# Epoch 70 Iteration 85
# 0.012744337
# Epoch 70 Iteration 86
# 0.0121456245
# Epoch 70 Iteration 87
# 0.0125173135
# Epoch 70 Iteration 88
# 0.012019764
# Epoch 70 Iteration 89
# 0.01233948
# Epoch 70 Iteration 90
# 0.011895969
# Epoch 70 Iteration 91
# 0.01215486
# Epoch 70 Iteration 92
# 0.011820629
# Epoch 70 Iteration 93
# 0.011998178
# Epoch 70 Iteration 94
# 0.011740648
# Epoch 70 Iteration 95
# 0.011844937
# Epoch 70 Iteration 96
# 0.011636127
# Epoch 70 Iteration 97
# 0.011724312
# Epoch 70 Iteration 98
# 0.011559729
# Epoch 70 Iteration 99
# 0.011640504
# Epoch 70 Iteration 100
# 0.01152358
# Epoch 70 Iteration 101
# 0.011552788
# Epoch 70 Iteration 102
# 0.011491621
# Epoch 70 Iteration 103
# 0.011485498
# Epoch 70 Iteration 104
# 0.011422685
# Epoch 70 Iteration 105
# 0.011367388
# Epoch 70 Iteration 106

# %%
# Try changing the batch size above to see if it runs???

#best so far: ~8.9% error using 128 hidden units, 32x compression, 150iterations,30 epochs
# ~9.72%,40epochs,150 iterations,128 hidden units, 504 points(16x compression)

# %%
plt.plot(train_losses[onwards:])
plt.plot(val_losses[onwards:])
plt.show()

# %%
#validation test


predictions = np.array([])
batch_input,batch_output = get_val_data()


rnn_model = build_graph(feed_previous=True) 
init = tf.global_variables_initializer()
with tf.Session() as sess:
 
    sess.run(init)
    #CHANGE THIS TO CHANGE MODEL LOADED IN WHEN FINISHED RUNNING
    saver = rnn_model['saver']().restore(sess, os.path.join('C:/Users/ellio/Documents/Dissertation/jupyter_code/Models/Univariate', 'univariate_ts_model0'))

    for series in range(batch_size):
        print(series+1,"/",batch_size)
        batch_val_input = batch_input[series]
        feed_dict = {rnn_model['enc_inp'][t]: batch_val_input[t].reshape(1,1) for t in range(input_seq_len)}
        feed_dict.update({rnn_model['target_seq'][t]: np.zeros([1, output_dim]) for t in range(output_seq_len)})
        final_preds = sess.run(rnn_model['reshaped_outputs'], feed_dict)

        predictions = np.append(predictions,final_preds)

print("Complete")

# %%
predictions = np.reshape(predictions,(batch_size, 63*training_size_mul))
truth = new_Y_val

# print(predictions.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-736721b3d566> in <module>()
#       8     return np.mean(np.abs((data - new_data) / data)) * 100
#       9
# ---> 10 predictions = np.reshape(predictions,(batch_size, 63*training_size_mul))
#      11 truth = new_Y_val
#      12
#
# NameError: name 'predictions' is not defined

# %%
predictions = rescale_data(predictions)
truth = rescale_data(truth)

# %%
errors = np.array([])
for err in range(batch_size):
    errors = np.append(errors,mse(predictions[err],batch_output[err]))


plt.plot(predictions[0])
plt.plot(truth[0])
plt.show()

print(mape(predictions,truth))

# %%
def rescale_data(data):
    return data*scaling_factors[0] + scaling_biases[0]

def mse(data,new_data):
    return np.mean((data-new_data)**2)



truth =  rescale_data(new_Y_val[:1].reshape(-1))
predictions = rescale_data(final_preds.reshape(-1))

print(truth)
print(predictions)

# preditions = np.delete(predictions,0)
plt.plot(predictions[1:])
plt.plot(truth[1:])
plt.show()
print(mse(truth[1:],predictions[1:]))

# %%
def scale(data):
    mean = np.mean(data)
    std = np.std(data)
    return mean, std, (data-mean)/std
    
def rescale(data,mean,std):
    return data*std + mean
    

x = np.array([[ 1., -1.,  2.],[ 2.,  0.,  0.],[ 0.,  1., -1.]])

# new_x = preprocessing.StandardScaler().fit(x)
mean, std, new_x = scale(x)
print(new_x)
print(rescale(new_x,mean,std))


print(preprocessing.normalize(x))
